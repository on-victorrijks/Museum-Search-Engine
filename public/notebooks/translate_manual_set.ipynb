# %%
from transformers import MarianMTModel, MarianTokenizer
import pandas as pd
from tqdm import tqdm
import os
import torch
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm
import json
from dotenv import load_dotenv
import numpy as np

# %%
# loading variables from .env file
load_dotenv("../../private_data/.env") 

# PARENT gets us to the root of the project
PARENT = "./../../"

MERGED_DATA_VALIDATION_SET = PARENT + os.getenv("MERGED_DATA_VALIDATION_SET")
MERGED_DATA_TESTING_SET = PARENT + os.getenv("MERGED_DATA_TESTING_SET")
MERGED_DATA_TRAINING_SET = PARENT + os.getenv("MERGED_DATA_TRAINING_SET")

# %%
BATCH_SIZE = 4
RUN_FR_EN = False
RUN_EN_NL = True

# %%
validation_captions = pd.read_csv(MERGED_DATA_VALIDATION_SET)
validation_captions
# Out:
#      recordID category       focus  \
# 0        5002  Tableau  luminosity
# 1       10900  Tableau  luminosity
# 2        5510   Dessin  luminosity
# 3        4576  Tableau     content
# 4        7689  Tableau     emotion
# ..        ...      ...         ...
# 949      3904  Tableau     content
# 950      4072  Tableau     content
# 951      1294  Tableau     emotion
# 952       482  Tableau      colors
# 953      8397   Dessin     emotion
#
#                                                caption  length_tokenization
# 0    Une fête, un repas, une foule en intérieur, de...                   30
# 1    Une femme joue du piano, elle lit une partitio...                   36
# 2    Un adolescente est assise contre le mur, elle ...                   28
# 3    Un paysage avec un ciel nuageux, un lac en fon...                   22
# 4    Des hommes barbus et moustachus qui discutent,...                   26
# ..                                                 ...                  ...
# 949  Une jeune femme avec longue robe blanche desce...                   27
# 950  Portrait d'une jeune femme qui lit un livre, v...                   24
# 951  Un paysage désolé avec des arbres sans feuille...                   31
# 952  Portrait d'une jeune femme avec une robe noire...                   33
# 953  Des personnes marchent de dos dans un port, le...                   32
#
# [954 rows x 5 columns]

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
class TranslationDataset(Dataset):
    def __init__(self, source_texts):
        self.source_texts = source_texts

    def __len__(self):
        return len(self.source_texts)

    def __getitem__(self, idx):
        return self.source_texts[idx]
    
def translate_batch(source_captions, model, tokenizer, device, batch_size=16):
    dataset = TranslationDataset(source_captions)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False)

    translated_texts = []

    for i, batch in enumerate(tqdm(dataloader)):
        inputs = tokenizer(batch, return_tensors="pt", padding=True, truncation=True)
        inputs = inputs.to(device)

        # Perform translation
        translated = model.generate(**inputs)

        # Decode translations
        translated_batch = [tokenizer.decode(t, skip_special_tokens=True) for t in translated]
        translated_texts.extend(translated_batch)
    
    resulting_df = validation_captions.copy()
    resulting_df["caption"] = translated_texts
    resulting_df["length_tokenization"] = np.nan
    return resulting_df

# %%
if RUN_FR_EN:
    model_fr_en = "Helsinki-NLP/opus-mt-fr-en"
    tokenizer_fr_en = MarianTokenizer.from_pretrained(model_fr_en)
    model_fr_en = MarianMTModel.from_pretrained(model_fr_en).to(device)

    validation_captions_EN = translate_batch(list(validation_captions["caption"]), model_fr_en, tokenizer_fr_en, device, batch_size=BATCH_SIZE)
    validation_captions_EN.to_csv(PARENT + os.getenv("MERGED_DATA_VALIDATION_SET_EN"), index=False)

validation_captions_EN = pd.read_csv(PARENT + os.getenv("MERGED_DATA_VALIDATION_SET_EN"))
validation_captions_EN
# Out:
#      recordID category       focus  \
# 0        5002  Tableau  luminosity
# 1       10900  Tableau  luminosity
# 2        5510   Dessin  luminosity
# 3        4576  Tableau     content
# 4        7689  Tableau     emotion
# ..        ...      ...         ...
# 949      3904  Tableau     content
# 950      4072  Tableau     content
# 951      1294  Tableau     emotion
# 952       482  Tableau      colors
# 953      8397   Dessin     emotion
#
#                                                caption  length_tokenization
# 0    A party, a meal, a crowd inside, children play...                  NaN
# 1    A woman plays the piano, she reads a score, th...                  NaN
# 2    A teenage girl is sitting against the wall, lo...                  NaN
# 3    A landscape with a cloudy sky, a lake in the b...                  NaN
# 4    Bearded and mustachu men who discuss, costumes...                  NaN
# ..                                                 ...                  ...
# 949  A young woman with a long white dress goes dow...                  NaN
# 950  Portrait of a young woman reading a book, blin...                  NaN
# 951  A sorry landscape with leafless trees, a cloud...                  NaN
# 952  Portrait of a young woman with a black dress a...                  NaN
# 953  People walk back in a harbour, cloudy sky, mat...                  NaN
#
# [954 rows x 5 columns]

# %%
if RUN_EN_NL:
    model_en_nl = "Helsinki-NLP/opus-mt-en-nl" # We cannot translate from French to Dutch using opus
    tokenizer_en_nl = MarianTokenizer.from_pretrained(model_en_nl)
    model_en_nl = MarianMTModel.from_pretrained(model_en_nl).to(device)

    validation_captions_NL = translate_batch(list(validation_captions_EN["caption"]), model_en_nl, tokenizer_en_nl, device, batch_size=BATCH_SIZE)
    validation_captions_NL.to_csv(PARENT + os.getenv("MERGED_DATA_VALIDATION_SET_NL"), index=False)
    validation_captions_NL
# Out:
# c:\Users\victo\Documents\Projects\Master-Thesis\.venv\lib\site-packages\transformers\models\marian\tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# 100%|██████████| 239/239 [01:38<00:00,  2.43it/s]

# %%
validation_captions_NL
# Out:
#      recordID category       focus  \
# 0        5002  Tableau  luminosity
# 1       10900  Tableau  luminosity
# 2        5510   Dessin  luminosity
# 3        4576  Tableau     content
# 4        7689  Tableau     emotion
# ..        ...      ...         ...
# 949      3904  Tableau     content
# 950      4072  Tableau     content
# 951      1294  Tableau     emotion
# 952       482  Tableau      colors
# 953      8397   Dessin     emotion
#
#                                                caption  length_tokenization
# 0    Een feestje, een maaltijd, een menigte binnen,...                  NaN
# 1    Een vrouw speelt piano, ze leest een partituur...                  NaN
# 2    Een tienermeisje zit tegen de muur, kijkt omho...                  NaN
# 3    Een landschap met een bewolkte hemel, een meer...                  NaN
# 4    Bebaarde en snorren mannen die bespreken, kost...                  NaN
# ..                                                 ...                  ...
# 949  Een jonge vrouw met een lange witte jurk gaat ...                  NaN
# 950  Portret van een jonge vrouw die een boek leest...                  NaN
# 951  Een zielig landschap met bladloze bomen, een b...                  NaN
# 952  Portret van een jonge vrouw met een zwarte jur...                  NaN
# 953  Mensen lopen terug in een haven, bewolkte luch...                  NaN
#
# [954 rows x 5 columns]
