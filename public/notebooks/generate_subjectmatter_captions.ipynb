# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import os
from tqdm import tqdm
from dotenv import load_dotenv 
import numpy as np
import json
from transformers import CLIPProcessor, CLIPModel
from transformers import AutoTokenizer

# %%
# loading variables from .env file
load_dotenv("../../private_data/.env") 

# PARENT gets us to the root of the project
PARENT = "./../../"

FOLDER_TABLE = PARENT + os.getenv("FOLDER_TABLE")
FILE_FABRITIUS_DATA = PARENT + os.getenv("FILE_FABRITIUS_DATA")
FILE_FABRITIUS_DATA_FILTERED = PARENT + os.getenv("FILE_FABRITIUS_DATA_FILTERED")
FILE_FABRITIUS_DATA_FILTERED_DOWNLOADED = PARENT + os.getenv("FILE_FABRITIUS_DATA_FILTERED_DOWNLOADED")
FOLDER_FIGURES = PARENT + os.getenv("FOLDER_FIGURES")
IMAGES_FOLDER = PARENT + os.getenv("IMAGES_FOLDER")
RECORD_IDS_TESTING_SET = PARENT + os.getenv("RECORD_IDS_TESTING_SET")
RECORD_IDS_VALIDATION_SET = PARENT + os.getenv("RECORD_IDS_VALIDATION_SET")
FILE_FABRITIUS_ICONOGRAPHIES_JSON = PARENT + os.getenv("FILE_FABRITIUS_ICONOGRAPHIES_JSON")

OUTPUT_MOONDREAM_CAPTIONS = PARENT + os.getenv("OUTPUT_MOONDREAM_CAPTIONS")
FILE_SUBJECTMATTERS_PARSED = PARENT + os.getenv("FILE_SUBJECTMATTERS_PARSED")

# %%
LANG = "FR"
TOKEN_LIMIT = 75 # Because of [SOS] and [EOS] tokens

# %%
base_name = "openai/clip-vit-large-patch14"
processor = CLIPProcessor.from_pretrained(base_name)
model = CLIPModel.from_pretrained(base_name)
tokenizer = AutoTokenizer.from_pretrained(base_name)

# %%
training_dataset = pd.DataFrame(columns=[
    "record_id",
    "row_type",
    "caption",
    "number_of_tokens"
])
training_dataset
# Out:
# Empty DataFrame
# Columns: [record_id, row_type, caption, number_of_tokens]
# Index: []

# %%
moondream_captions = pd.read_csv(OUTPUT_MOONDREAM_CAPTIONS)
moondream_captions.head(5)
# Out:
#    recordID                                               task  \
# 0        64                                            caption
# 1        64                          What objects do you see ?
# 2        64                           What colors do you see ?
# 3        64                     Is this image bright or dark ?
# 4        64  What emotion do you feel when looking at this ...
#
#                                                   EN  \
# 0   A religious scene features a central figure o...
# 1   In the image, there are two people on a cross...
# 2   The image features a painting with a predomin...
# 3                                 The image is dark.
# 4   When looking at this image, I feel a sense of...
#
#                                                   FR  \
# 0  Une scène religieuse présente une figure centr...
# 1  À l'image, il y a deux personnes sur une croix...
# 2  L'image présente une peinture avec un schéma d...
# 3                                L'image est sombre.
# 4  En regardant cette image, je ressens un sentim...
#
#                                                   NL
# 0  Een religieuze scène toont een centrale figuur...
# 1  In het beeld zijn er twee mensen aan het kruis...
# 2  De afbeelding is voorzien van een schilderij m...
# 3                               Het beeld is donker.
# 4  Als ik naar dit beeld kijk, voel ik een gevoel...

# %%
subjectmatter_json = json.loads(open(FILE_SUBJECTMATTERS_PARSED, "r", encoding="utf-8").read())
subjectmatter_json
# Out:
# [{'recordID': 64,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'scène',
#        'children': [{'name': 'homme', 'children': []},
#         {'name': 'femme', 'children': []},
#         {'name': 'enfant', 'children': []},
#         {'name': 'vêtement', 'children': [{'name': 'habit', 'children': []}]},
#         {'name': 'robe', 'children': []},
#         {'name': 'ceinture', 'children': []},
#         {'name': 'couvre-chef',
#          'children': [{'name': 'chapeau', 'children': []}]},
#         {'name': 'coiffe', 'children': []},
#         {'name': 'arme', 'children': [{'name': 'épée', 'children': []}]},
#         {'name': 'animal', 'children': [{'name': 'cheval', 'children': []}]},
#         {'name': 'croix', 'children': []},
#         {'name': 'mort', 'children': []}]},
#       {'name': 'fond de paysage',
#        'children': [{'name': 'ville', 'children': []},
#         {'name': 'tour', 'children': []},
#         {'name': 'montagne', 'children': []},
#         {'name': 'eau', 'children': []},
#         {'name': 'forêt', 'children': []},
#         {'name': 'rocher', 'children': []}]}]},
#     'flattened': ['scène',
#      'homme',
#      'femme',
#      'enfant',
#      'vêtement',
#      'habit',
#      'robe',
#      'ceinture',
#      'couvre-chef',
#      'chapeau',
#      'coiffe',
#      'arme',
#      'épée',
#      'animal',
#      'cheval',
#      'croix',
#      'mort',
#      'fond de paysage',
#      'ville',
#      'tour',
#      'montagne',
#      'eau',
#      'forêt',
#      'rocher']},
#    'subjectMatterIconographicTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'scène biblique',
#        'children': [{'name': '[SO]',
#          'children': [{'name': 'Nouveau Testament', 'children': []},
#           {'name': 'Evangiles', 'children': []},
#           {'name': 'Passion', 'children': []}]},
#         {'name': 'Calvaire', 'children': []},
#         {'name': 'Crucifixion', 'children': []},
#         {'name': 'Jésus', 'children': [{'name': 'Christ', 'children': []}]},
#         {'name': 'sainte Marie',
#          'children': [{'name': 'Vierge', 'children': []}]},
#         {'name': 'Jérusalem', 'children': []}]}]},
#     'flattened': ['scène biblique',
#      '[SO]',
#      'Nouveau Testament',
#      'Evangiles',
#      'Passion',
#      'Calvaire',
#      'Crucifixion',
#      'Jésus',
#      'Christ',
#      'sainte Marie',
#      'Vierge',
#      'Jérusalem']},
#    'subjectMatterConceptualTerms': {'tree': {}, 'flattened': []}},
#   'unstructured': {'subjectMatterIconographicInterpretation': nan,
#    'subjectMatterGeneralSubjectDescription': nan,
#    'subjectMatterSpecificSubjectIdentification': nan}},
#  {'recordID': 77,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'figure',
#        'children': [{'name': 'femme', 'children': []},
#         {'name': 'arbre', 'children': []},
#         {'name': 'table', 'children': []},
#         {'name': 'chaise', 'children': []}]}]},
#     'flattened': ['figure', 'femme', 'arbre', 'table', 'chaise']},
#    'subjectMatterIconographicTerms': {'tree': {}, 'flattened': []},
#    'subjectMatterConceptualTerms': {'tree': {}, 'flattened': []}},
#   'unstructured': {'subjectMatterIconographicInterpretation': nan,
#    'subjectMatterGeneralSubjectDescription': nan,
#    'subjectMatterSpecificSubjectIdentification': nan}},
#  {'recordID': 78,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'figure',
#        'children': [{'name': 'enfant', 'children': []},
#         {'name': 'de face', 'children': []},
#         {'name': 'robe', 'children': []},
#         {'name': 'noeud', 'children': []},
#         {'name': 'intérieur', 'children': []},
#         {'name': 'chaise', 'children': []}]}]},
#     'flattened': ['figure',
#      'enfant',
#      'de face',
#      'robe',
#      'noeud',
#      'intérieur',
#      'chaise']},
#    'subjectMatterIconographicTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'portrait',
#        'children': [{'name': 'fillette',
#          'children': [{'name': 'Louise van der Hecht', 'children': []}]}]}]},
#     'flattened': ['portrait', 'fillette', 'Louise van der Hecht']},
#    'subjectMatterConceptualTerms': {'tree': {}, 'flattened': []}},
#   'unstructured': {'subjectMatterIconographicInterpretation': "C'est à ses portraits que Khnopff doit sa renommée internationale, et surtout la reconnaissance dont il jouit dans sa propre classe sociale, la grande bourgeoisie et l'aristocratie. Il commence par peindre des enfants, qui, malgré une apparence juvénile, produisent, par l'attitude et l'expression du visage, une sensation de maturité. Khnopff ne nous propose pas un instantané, mais une interprétation intemporelle. Louise van der Hecht a trois ans lorsque Khnopff entreprend son portrait. L'attention du spectateur ne peut que se focaliser sur son visage: jamais petite fille n'a eu l'air moins infantine. Elle paraît si sérieuse et si absorbée dans ses pensées que nous avons l'impression de soutenir le regard pénétrant d'une femme. Assise de face sur une chaise, elle semble prendre appui sur ses mains. Sa contenance trahit une certaine gêne, tandis que son regard nous tient à distance. Elle oppose le spectateur un visage fermé, qui ne manque pourtant pas de charme sous l'auréole de ses cheveux blonds (d'après Inga Rossi-Schrimpf, in cat. Khnopff)",
#    'subjectMatterGeneralSubjectDescription': nan,
#    'subjectMatterSpecificSubjectIdentification': nan}},
#  {'recordID': 79,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'figure',
#        'children': [{'name': 'femme', 'children': []},
#         {'name': 'main', 'children': []},
#         {'name': 'intérieur', 'children': []},
#         {'name': 'salon', 'children': []},
#         {'name': 'fauteuil', 'children': []},
#         {'name': 'souche de cheminée', 'children': []},
#         {'name': 'miroir', 'children': []},
#         {'name': 'instrument de musique',
#          'children': [{'name': 'piano', 'children': []}]}]}]},
#     'flattened': ['figure',
#      'femme',
#      'main',
#      'intérieur',
#      'salon',
#      'fauteuil',
#      'souche de cheminée',
#      'miroir',
#      'instrument de musique',
#      'piano']},
#    'subjectMatterIconographicTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'scène',
#        'children': [{'name': 'bourgeoisie', 'children': []}]},
#       {'name': 'méditation', 'children': []},
#       {'name': 'musique', 'children': []}]},
#     'flattened': ['scène', 'bourgeoisie', 'méditation', 'musique']},
#    'subjectMatterConceptualTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'Robert Schumann', 'children': []}]},
#     'flattened': ['Robert Schumann']}},
#   'unstructured': {'subjectMatterIconographicInterpretation': "La scène baigne dans une atmosphère de mélancolie et de contemplation. Le vrai sujet du tableau est l'effet émotionnel de la musique. La femme ne se trouve pas vraiment dans ce monde, mais plongée dans ses souvenirs. Ses émotions ne sont pas destinées au spectateur. Toute l'attention est attirée par cette main, le point central de la composition. Cette main qui la protège du spectateur. On peut, pour ainsi dire, 'l'entendre écouter' la musique. Khnopff était un grand admirateur de la musique de Schumann. C'est sa mère, dont il peignit déjà un portrait en 1881, qui servit de modèle pour ce personnage féminin (d'après Sophie Van Vliet, in cat. Khnopff)",
#    'subjectMatterGeneralSubjectDescription': nan,
#    'subjectMatterSpecificSubjectIdentification': nan}},
#  {'recordID': 80,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'scène',
#        'children': [{'name': 'être imaginaire',
#          'children': [{'name': 'guépard', 'children': []},
#           {'name': 'femme', 'children': []}]},
#         {'name': 'homme',
#          'children': [{'name': 'jeune homme', 'children': []}]},
#         {'name': 'paysage', 'children': []},
#         {'name': 'sceptre', 'children': []}]}]},
#     'flattened': ['scène',
#      'être imaginaire',
#      'guépard',
#      'femme',
#      'homme',
#      'jeune homme',
#      'paysage',
#      'sceptre']},
#    'subjectMatterIconographicTerms': {'tree': {}, 'flattened': []},
#    'subjectMatterConceptualTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'androgyne', 'children': []}]},
#     'flattened': ['androgyne']}},
#   'unstructured': {'subjectMatterIconographicInterpretation': "Sur un fond de marbre et de paysage antique de couleur rouge, un androgyne s'incline lentement vers la caresse d'un sphinx au corps de guépard, d'une souplesse toute féminine. Les yeux de l'androgyne fixent sans voir, comme en rêve. Omniprésent dans l'oeuvre de Khnopff, le thème de l'androgyne précède de très loin l'engagement du surréalisme à l'égard de ce grand mythe fondamental. Khnopff interrogé sur ses intentions, répondit que le tableau du guépard est beaucoup moins mystique qu'on ne le croit. Ce n'est qu'une allégorie tout à fait courante. L'homme se trouve devant un choix : le plaisir ou la puissance. Au Moyen Age, le léopard était un des symboles de la volupté. Ce léopard n'est d'ailleurs pas un léopard mais un guépard, car celui-ci est parmi les animaux sauvages le plus rampant et le plus proche du serpent, comme il le précisait, tout en ajoutant ne pas l'avoir choisi pour ses qualités mystiques, mais pour des raisons plastiques. On sait que la femme joue un grand rôle dans le symbolisme belge car elle incarne à elle seule toute la dualité et l'ambiguïté du monde. Khnopff et Rops sont parmi les symbolistes de notre pays ceux qui ont le mieux saisi et exprimé son mystère. Chez Khnopff, la femme est tour à tour l'ange, la muse, l'amie. Mais elle se fait aussi tentatrice, femme fatale et perverse, symbole même du Vice suprême. Dans 'Des caresses', Khnopff représente cette beauté mystérieuse mais la femme se vend et son maître devient Satan. C'est ce que Félicien Rops retient d'elle à travers tout son oeuvre (cf. inv. 11996). C'est la femme dévorante, c'est aussi la mort. La confrontation de l'androgyne et de la sphinge dans un paysage imaginaire, peuplé de colonnes bleues et d'inscriptions cabalistiques, évoquant vaguement des hiéroglyphes, soulève maints décryptages. Symbolisation du pouvoir, de la domination, de la séduction? N'est-ce pas plutôt l'image de Khnopff lui-même, confronté à son reflet, sa soeur Marguerite, muse inaccessible? Peut-être aussi l'éternelle vision d'Oedipe et du sphinx? L'oeuvre nous interroge sans fin et ne cessera pas de le faire (d'après Gisèle Ollinger-Zinque, in cat. Khnopff)",
#    'subjectMatterGeneralSubjectDescription': 'Un léopard à tête de femme se presse contre un jeune homme au torse nu, qui tient un sceptre, devant un paysage imaginaire.',
#    'subjectMatterSpecificSubjectIdentification': nan}},
#  {'recordID': 81,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'scène',
#        'children': [{'name': 'femme', 'children': []},
#         {'name': 'en pied', 'children': []},
#         {'name': 'robe', 'children': []},
#         {'name': 'chapeau', 'children': []},
#         {'name': 'gant', 'children': []}]}]},
#     'flattened': ['scène', 'femme', 'en pied', 'robe', 'chapeau', 'gant']},
#    'subjectMatterIconographicTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'portrait',
#        'children': [{'name': 'famille', 'children': []},
#         {'name': 'Marguerite Khnopff', 'children': []},
#         {'name': 'sport',
#          'children': [{'name': 'tennis', 'children': []}]}]}]},
#     'flattened': ['portrait',
#      'famille',
#      'Marguerite Khnopff',
#      'sport',
#      'tennis']},
#    'subjectMatterConceptualTerms': {'tree': {}, 'flattened': []}},
#   'unstructured': {'subjectMatterIconographicInterpretation': "Les femmes dans ce pastel sont le reflet physique de la vie intérieure qui ne peut être représentée de manière sensorielle. Ces monades se composent de souvenirs immatériels, de fragments de différents moments du passé qui surgissent pour expliquer, ou mieux encore pour déterminer le présent. Henri Bergson avait déjà avancé l'idée selon laquelle les souvenirs peuvent influencer l'observation. Depuis, des recherches ont permis d'affirmer que l'influence de la mémoire peut être tellement grande qu'elle devient un obstacle à l'observation. Ce sont des 'Memories', qui reflètent le monde intérieur et qui sont le vrai thème de cette oeuvre signée Khnopff. L'histoire explicite et explicative cède la place à la prise de conscience du caractère fortuit des phénomènes. Par la même occasion, dès que la contrainte de la pensée unique disparaît, l'artiste commence à saisir les possibilités insoupçonnées du processus artistique. 'Memories' marque une rupture définitive avec l'unité du temps, du lieu et de l'action. Le modèle étant sa soeur Marguerite, certains pensent que le thème souligne la grande affection que l'artiste lui portait. L'oeuvre perdrait ainsi une partie essentielle de son caractère universel, pour devenir une illustration anecdotique. La septième femme, la plus belle, ne ressemble nullement à sa soeur, même si elle porte la même robe longue que Marguerite sur le portrait de 1887 (MRBAB, dépôt). Marguerite était tout simplement le type de femme qu'il lui fallait pour cette composition (sa soeur étant en outre disposée à deux reprises à se donner beaucoup de peine pour changer de vêtements), sans pour cela porter atteinte à l'idée qu'il vénérait sa soeur, comme le soulignent bon nombre d'auteurs (d'après Frederik Leen, in cat. Khnopff)",
#    'subjectMatterGeneralSubjectDescription': "Sept femmes portant chacune une raquette de tennis, sur un terrain couvert d'herbe.",
#    'subjectMatterSpecificSubjectIdentification': 'Sept fois la soeur du peintre, en pied, dans sept tenues différentes.'}},
#  {'recordID': 82,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'groupe de figures',
#        'children': [{'name': 'homme', 'children': []},
#         {'name': 'armure', 'children': []},
#         {'name': 'casque', 'children': []},
#         {'name': 'être imaginaire',
#          'children': [{'name': 'tigre', 'children': []}]},
#         {'name': 'tête', 'children': [{'name': 'femme', 'children': []}]},
#         {'name': 'balustrade', 'children': []}]}]},
#     'flattened': ['groupe de figures',
#      'homme',
#      'armure',
#      'casque',
#      'être imaginaire',
#      'tigre',
#      'tête',
#      'femme',
#      'balustrade']},
#    'subjectMatterIconographicTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'ange', 'children': []}]},
#     'flattened': ['ange']},
#    'subjectMatterConceptualTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'hybride fabuleux',
#        'children': [{'name': 'sphinx', 'children': []}]}]},
#     'flattened': ['hybride fabuleux', 'sphinx']}},
#   'unstructured': {'subjectMatterIconographicInterpretation': nan,
#    'subjectMatterGeneralSubjectDescription': nan,
#    'subjectMatterSpecificSubjectIdentification': nan}},
#  {'recordID': 105,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'groupe de figures',
#        'children': [{'name': 'femme',
#          'children': [{'name': 'nue', 'children': []}]},
#         {'name': 'enfant',
#          'children': [{'name': 'être imaginaire', 'children': []}]},
#         {'name': 'aile', 'children': []},
#         {'name': 'dans les airs', 'children': []},
#         {'name': 'en vol', 'children': []},
#         {'name': 'homme', 'children': [{'name': 'barbe', 'children': []}]},
#         {'name': 'patte', 'children': [{'name': 'bouc', 'children': []}]},
#         {'name': 'animal', 'children': [{'name': 'cheval', 'children': []}]},
#         {'name': 'dauphin', 'children': []},
#         {'name': 'poisson', 'children': []},
#         {'name': 'raie', 'children': []},
#         {'name': 'plie', 'children': []},
#         {'name': 'anguille', 'children': []},
#         {'name': 'étoile de mer', 'children': []},
#         {'name': 'homard', 'children': []},
#         {'name': 'crustacé', 'children': [{'name': 'huître', 'children': []}]},
#         {'name': 'coquillage', 'children': []}]},
#       {'name': '<group>',
#        'children': [{'name': 'fête', 'children': []},
#         {'name': 'banquet', 'children': []},
#         {'name': 'table', 'children': []},
#         {'name': 'assiette', 'children': []},
#         {'name': 'plat', 'children': []},
#         {'name': 'bol', 'children': []},
#         {'name': 'cruche', 'children': []},
#         {'name': 'vaisselle', 'children': []},
#         {'name': 'verrerie', 'children': []},
#         {'name': 'verre à pied', 'children': []},
#         {'name': 'hanap', 'children': []},
#         {'name': 'instrument de musique',
#          'children': [{'name': 'tambourin', 'children': []}]},
#         {'name': 'cor', 'children': []},
#         {'name': 'danse', 'children': []},
#         {'name': 'plante', 'children': []},
#         {'name': 'fleur', 'children': []},
#         {'name': 'guirlande', 'children': []},
#         {'name': 'légume',
#          'children': [{'name': 'artichaut', 'children': []}]},
#         {'name': 'fruit', 'children': [{'name': 'melon', 'children': []}]},
#         {'name': 'fruit de la passion', 'children': []},
#         {'name': 'raisin', 'children': []},
#         {'name': 'arme', 'children': [{'name': 'flèche', 'children': []}]},
#         {'name': 'arc', 'children': []},
#         {'name': 'trident', 'children': []},
#         {'name': 'tonneau', 'children': []},
#         {'name': 'grotte', 'children': []},
#         {'name': 'eau', 'children': [{'name': 'mer', 'children': []}]}]}]},
#     'flattened': ['groupe de figures',
#      'femme',
#      'nue',
#      'enfant',
#      'être imaginaire',
#      'aile',
#      'dans les airs',
#      'en vol',
#      'homme',
#      'barbe',
#      'patte',
#      'bouc',
#      'animal',
#      'cheval',
#      'dauphin',
#      'poisson',
#      'raie',
#      'plie',
#      'anguille',
#      'étoile de mer',
#      'homard',
#      'crustacé',
#      'huître',
#      'coquillage',
#      'fête',
#      'banquet',
#      'table',
#      'assiette',
#      'plat',
#      'bol',
#      'cruche',
#      'vaisselle',
#      'verrerie',
#      'verre à pied',
#      'hanap',
#      'instrument de musique',
#      'tambourin',
#      'cor',
#      'danse',
#      'plante',
#      'fleur',
#      'guirlande',
#      'légume',
#      'artichaut',
#      'fruit',
#      'melon',
#      'fruit de la passion',
#      'raisin',
#      'arme',
#      'flèche',
#      'arc',
#      'trident',
#      'tonneau',
#      'grotte',
#      'eau',
#      'mer']},
#    'subjectMatterIconographicTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'scène mythologique',
#        'children': [{'name': 'mariage', 'children': []},
#         {'name': 'Ariane', 'children': []},
#         {'name': 'Bacchus', 'children': []},
#         {'name': 'divinité', 'children': []},
#         {'name': 'nymphe', 'children': []},
#         {'name': 'Cupidon', 'children': []},
#         {'name': 'satyre', 'children': []}]}]},
#     'flattened': ['scène mythologique',
#      'mariage',
#      'Ariane',
#      'Bacchus',
#      'divinité',
#      'nymphe',
#      'Cupidon',
#      'satyre']},
#    'subjectMatterConceptualTerms': {'tree': {}, 'flattened': []}},
#   'unstructured': {'subjectMatterIconographicInterpretation': "Ce tableau représente un épisode douloureux de l'histoire de Thésée. Après avoir vaincu le Minotaure, le héros athénien fuit l'île de Crète emmenant avec lui Ariane, la fille du roi Minos. A l'île de Naxos, où il accoste, une grande douleur l'attend. Bacchus lui ordonne, en songe, de lui offrir Ariane comme épouse. Brisé de chagrin, Thésée se soumet cependant à la volonté divine, abandonne la malheureuse princesse et retourne à Athènes. Ici, Ariane a quitté l'embarcation de Thésée et est emportée par des amours et les dieux de la mer vers Bacchus, ivre, soutenu par des satyres. (d'après Willy Laureyssens)",
#    'subjectMatterGeneralSubjectDescription': nan,
#    'subjectMatterSpecificSubjectIdentification': nan}},
#  {'recordID': 114,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'groupe de figures',
#        'children': [{'name': 'homme',
#          'children': [{'name': 'barbe', 'children': []}]},
#         {'name': 'vieux', 'children': []},
#         {'name': 'massue', 'children': []},
#         {'name': 'couronne',
#          'children': [{'name': 'feuille', 'children': []}]},
#         {'name': 'animal',
#          'children': [{'name': 'oiseau', 'children': []},
#           {'name': 'aigle', 'children': []}]},
#         {'name': 'vase', 'children': []},
#         {'name': 'fleur', 'children': []},
#         {'name': 'arme', 'children': [{'name': 'flèche', 'children': []}]},
#         {'name': 'épée', 'children': []},
#         {'name': 'bouclier', 'children': []},
#         {'name': 'casque', 'children': []},
#         {'name': 'carquois', 'children': []},
#         {'name': 'jeune homme', 'children': []},
#         {'name': 'enfant', 'children': [{'name': 'nu', 'children': []}]},
#         {'name': 'aile', 'children': []},
#         {'name': 'être imaginaire', 'children': []},
#         {'name': 'nuage', 'children': []},
#         {'name': 'ciel', 'children': []},
#         {'name': 'rayons lumineux', 'children': []}]},
#       {'name': 'architecture',
#        'children': [{'name': 'balustrade', 'children': []}]},
#       {'name': 'plafond', 'children': []}]},
#     'flattened': ['groupe de figures',
#      'homme',
#      'barbe',
#      'vieux',
#      'massue',
#      'couronne',
#      'feuille',
#      'animal',
#      'oiseau',
#      'aigle',
#      'vase',
#      'fleur',
#      'arme',
#      'flèche',
#      'épée',
#      'bouclier',
#      'casque',
#      'carquois',
#      'jeune homme',
#      'enfant',
#      'nu',
#      'aile',
#      'être imaginaire',
#      'nuage',
#      'ciel',
#      'rayons lumineux',
#      'architecture',
#      'balustrade',
#      'plafond']},
#    'subjectMatterIconographicTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'scène mythologique',
#        'children': [{'name': 'Enée',
#          'children': [{'name': 'vie', 'children': []}]},
#         {'name': 'Hercule', 'children': []},
#         {'name': 'Jupiter', 'children': []},
#         {'name': 'putto', 'children': []},
#         {'name': 'divinité', 'children': []},
#         {'name': 'Didon', 'children': []},
#         {'name': 'Vénus', 'children': []},
#         {'name': 'Anchise', 'children': []}]}]},
#     'flattened': ['scène mythologique',
#      'Enée',
#      'vie',
#      'Hercule',
#      'Jupiter',
#      'putto',
#      'divinité',
#      'Didon',
#      'Vénus',
#      'Anchise']},
#    'subjectMatterConceptualTerms': {'tree': {}, 'flattened': []}},
#   'unstructured': {'subjectMatterIconographicInterpretation': nan,
#    'subjectMatterGeneralSubjectDescription': nan,
#    'subjectMatterSpecificSubjectIdentification': nan}},
#  {'recordID': 119,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'figure',
#        'children': [{'name': 'homme',
#          'children': [{'name': 'nu', 'children': []}]},
#         {'name': 'mort', 'children': []},
#         {'name': 'arme', 'children': [{'name': 'couteau', 'children': []}]},
#         {'name': 'sang', 'children': []},
#         {'name': 'lettre', 'children': []},
#         {'name': "instrument d'écriture",
#          'children': [{'name': 'plume', 'children': []}]},
#         {'name': 'encrier', 'children': []}]},
#       {'name': 'scène', 'children': [{'name': 'bain', 'children': []}]}]},
#     'flattened': ['figure',
#      'homme',
#      'nu',
#      'mort',
#      'arme',
#      'couteau',
#      'sang',
#      'lettre',
#      "instrument d'écriture",
#      'plume',
#      'encrier',
#      'scène',
#      'bain']},
#    'subjectMatterIconographicTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'portrait',
#        'children': [{'name': 'Jean Paul Marat', 'children': []}]},
#       {'name': 'meurtre', 'children': []},
#       {'name': 'révolution française', 'children': []}]},
#     'flattened': ['portrait',
#      'Jean Paul Marat',
#      'meurtre',
#      'révolution française']},
#    'subjectMatterConceptualTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'martyre', 'children': []},
#       {'name': 'Marie-Anne Charlotte Corday', 'children': []},
#       {'name': 'Louis XVI', 'children': []}]},
#     'flattened': ['martyre', 'Marie-Anne Charlotte Corday', 'Louis XVI']}},
#   'unstructured': {'subjectMatterIconographicInterpretation': 'Le 13 juillet 1793 Marie-Anne Charlotte Corday, partisane des Girondins, se fit introduire auprès de Marat, sous prétexte de lui communiquer des renseignements sur ceux-ci et le poignarda. Marat, qui souffrait d\'une maladie de la peau que seuls des bains soulageaient, travaillait souvent dans sa baignoire. Il publiait depuis 1789 le journal "L\'ami du peuple" : il tient encore son "arme", la plume, en main, représentée ici tout près de l\'arme encore ensanglantée du crime. On demanda à David d\'organiser la pompe des funérailles et de peindre un tableau commémoratif. De la mythologie classique qui jusqu\'alors constituait sa galerie de modèles, David passe ici à un héros de l\'histoire contemporaine. Il idéalise son héros en s\'en tenant à un strict réalisme. Le peintre est à ce moment l\'artiste français le plus en vue mais aussi un ami personnel de la victime ; tous deux ont voté, à la Convention, la mort de Louis XVI. (d\'après Frederik Leen, in \'Musée d\'Art Moderne. Oeuvres choisies\')',
#    'subjectMatterGeneralSubjectDescription': 'Un homme avec une blessure à la poitrine gît, mort, dans une baignoire ; il tient une plume et une lettre ; sur une table sont posés une autre plume et un encrier ; sur le sol, un couteau ensanglanté.',
#    'subjectMatterSpecificSubjectIdentification': 'Marat assassiné'}},
#  {'recordID': 121,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'figure',
#        'children': [{'name': 'enfant', 'children': []},
#         {'name': 'robe', 'children': []},
#         {'name': 'noeud', 'children': []},
#         {'name': 'gant', 'children': []},
#         {'name': 'manteau',
#          'children': [{'name': 'fourrure', 'children': []}]},
#         {'name': 'coiffe', 'children': []}]}]},
#     'flattened': ['figure',
#      'enfant',
#      'robe',
#      'noeud',
#      'gant',
#      'manteau',
#      'fourrure',
#      'coiffe']},
#    'subjectMatterIconographicTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'portrait',
#        'children': [{'name': 'fillette',
#          'children': [{'name': 'Germaine Wiener', 'children': []}]}]}]},
#     'flattened': ['portrait', 'fillette', 'Germaine Wiener']},
#    'subjectMatterConceptualTerms': {'tree': {}, 'flattened': []}},
#   'unstructured': {'subjectMatterIconographicInterpretation': nan,
#    'subjectMatterGeneralSubjectDescription': nan,
#    'subjectMatterSpecificSubjectIdentification': nan}},
#  {'recordID': 123,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'scène',
#        'children': [{'name': 'homme', 'children': []},
#         {'name': 'femme', 'children': [{'name': 'nu', 'children': []}]},
#         {'name': 'être imaginaire',
#          'children': [{'name': 'aile', 'children': []}]},
#         {'name': 'arme', 'children': [{'name': 'épée', 'children': []}]},
#         {'name': 'arc', 'children': []},
#         {'name': 'flèche', 'children': []},
#         {'name': 'lance', 'children': []},
#         {'name': 'casque', 'children': []},
#         {'name': 'bouclier', 'children': []},
#         {'name': 'oiseau', 'children': []}]},
#       {'name': 'lit', 'children': []},
#       {'name': 'architecture', 'children': []},
#       {'name': 'colonne', 'children': []},
#       {'name': 'fleur', 'children': []},
#       {'name': 'nuage', 'children': []},
#       {'name': 'cruche', 'children': []}]},
#     'flattened': ['scène',
#      'homme',
#      'femme',
#      'nu',
#      'être imaginaire',
#      'aile',
#      'arme',
#      'épée',
#      'arc',
#      'flèche',
#      'lance',
#      'casque',
#      'bouclier',
#      'oiseau',
#      'lit',
#      'architecture',
#      'colonne',
#      'fleur',
#      'nuage',
#      'cruche']},
#    'subjectMatterIconographicTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'figures mythologiques',
#        'children': [{'name': 'divinité',
#          'children': [{'name': 'Mars', 'children': []}]},
#         {'name': 'Vénus', 'children': []},
#         {'name': 'Cupidon', 'children': []}]}]},
#     'flattened': ['figures mythologiques',
#      'divinité',
#      'Mars',
#      'Vénus',
#      'Cupidon']},
#    'subjectMatterConceptualTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'allégorie',
#        'children': [{'name': 'amour', 'children': []}]},
#       {'name': 'paix', 'children': []}]},
#     'flattened': ['allégorie', 'amour', 'paix']}},
#   'unstructured': {'subjectMatterIconographicInterpretation': "Dans un décor surréaliste avec temple flottant dans les nuages, Vénus et ses acolytes, les trois grâces, et Cupidon, s'activent. Mars, le dieu de la guerre, se laisse dépouiller de ses armes avec complaisance et succombe aux charmes de Vénus. Il se réjouit déjà de la suite des événements ; on lui délace ses sandales, dernières pièces d'habillement. Pourtant on peut se demander pourquoi Amour n'a pas encore décoché ses flèches, celle en or qui déclenche l'amour, celle de plomb qui l'éteint.  (d'après Dominique Marechal, in 'Musée d'Art Moderne. Oeuvres choisies')",
#    'subjectMatterGeneralSubjectDescription': "Un homme et une femme nus sur un lit ; l'homme a encore ses sandales, que lui délace un jeune garçon ailé qui porte un carquois et a déposé son arc ; l'homme porte une couronne de fleurs autour de la poitrine, et la femme va lui en poser une autre sur la tête ; l'homme tient une lance, et tend une épée vers une jeune femme, qui tient un bouclier ; une autre pose un casque sur un pilier, une autre encore sert à boire dans une coupe ; la scène prend place sur des nuages ; à l'arrière-plan se trouve un édifice à colonnes, de style classique.",
#    'subjectMatterSpecificSubjectIdentification': "(d'après Dominique Marechal)"}},
#  {'recordID': 126,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'scène',
#        'children': [{'name': 'homme', 'children': []},
#         {'name': 'femme', 'children': []},
#         {'name': 'vêtement',
#          'children': [{'name': "à l'antique", 'children': []}]}]}]},
#     'flattened': ['scène', 'homme', 'femme', 'vêtement', "à l'antique"]},
#    'subjectMatterIconographicTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'Auguste', 'children': []},
#       {'name': 'empereur', 'children': []},
#       {'name': 'Octavie',
#        'children': [{'name': 'évanouissement', 'children': []}]},
#       {'name': 'Livie', 'children': []},
#       {'name': '[SO] Virgile',
#        'children': [{'name': 'Enéide', 'children': []}]}]},
#     'flattened': ['Auguste',
#      'empereur',
#      'Octavie',
#      'évanouissement',
#      'Livie',
#      '[SO] Virgile',
#      'Enéide']},
#    'subjectMatterConceptualTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'Rome', 'children': []},
#       {'name': 'Marcellus', 'children': []},
#       {'name': 'Antiquité', 'children': []}]},
#     'flattened': ['Rome', 'Marcellus', 'Antiquité']}},
#   'unstructured': {'subjectMatterIconographicInterpretation': 'Au milieu de la nuit, le poète romain Virgile, que l\'on n\'aperçoit pas sur le tableau, fait la lecture de l\'Enéide, à l\'attention de la famille impériale. En entendant les mots "Tu Marcellus eris", Octavie, terrassée par l\'émotion, s\'évanouit sur les genoux de son frère, l\'empereur Auguste. Sa belle-soeur Livie, la troisième épouse de l\'empereur, demeure impassible et lui lance un regard féroce. D\'un geste solennel, Auguste, ému, impose le silence au narrateur invisible tandis que de son autre main il soutient tendrement sa soeur. Les paroles "Tu Marcellus eris" rappellent douloureusement à Octavie la mort de son fils, le successeur désigné de l\'empereur. Il avait été tué au cours d\'un complot, vraisemblablement perpétré par Livie, qui aurait préféré voir son propre fils prendre la place de l\'empereur.  (d\'après Dominique Marechal, in \'Musée d\'Art Moderne. Oeuvres choisies\')',
#    'subjectMatterGeneralSubjectDescription': "Groupe de personnages vêtus à l'antique ; l'homme assis lève la main, une jeune femme est couchée, les yeux fermés, sur ses genoux ; une autre femme la regarde d'un air sévère.",
#    'subjectMatterSpecificSubjectIdentification': "L'empereur Auguste écoute la lecture de l'Enéide par Virgile, en compagnie de sa soeur Octavie, et de son épouse Livie."}},
#  {'recordID': 128,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'groupe',
#        'children': [{'name': 'homme', 'children': []},
#         {'name': 'femme', 'children': []},
#         {'name': 'enfant', 'children': []},
#         {'name': 'vêtement', 'children': [{'name': 'habit', 'children': []}]},
#         {'name': 'robe', 'children': []},
#         {'name': 'col', 'children': [{'name': 'dentelle', 'children': []}]},
#         {'name': 'tissu', 'children': []},
#         {'name': 'coiffure', 'children': []},
#         {'name': 'main', 'children': []},
#         {'name': 'livre', 'children': []}]},
#       {'name': 'intérieur', 'children': []},
#       {'name': 'meuble de rangement', 'children': []},
#       {'name': 'armoire', 'children': []},
#       {'name': 'fauteuil', 'children': []},
#       {'name': 'minéral', 'children': []}]},
#     'flattened': ['groupe',
#      'homme',
#      'femme',
#      'enfant',
#      'vêtement',
#      'habit',
#      'robe',
#      'col',
#      'dentelle',
#      'tissu',
#      'coiffure',
#      'main',
#      'livre',
#      'intérieur',
#      'meuble de rangement',
#      'armoire',
#      'fauteuil',
#      'minéral']},
#    'subjectMatterIconographicTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'portrait',
#        'children': [{'name': 'de Hemptinne', 'children': []},
#         {'name': 'de Lathuy', 'children': []}]},
#       {'name': 'famille', 'children': []},
#       {'name': 'couple', 'children': []},
#       {'name': 'fillette', 'children': []}]},
#     'flattened': ['portrait',
#      'de Hemptinne',
#      'de Lathuy',
#      'famille',
#      'couple',
#      'fillette']},
#    'subjectMatterConceptualTerms': {'tree': {}, 'flattened': []}},
#   'unstructured': {'subjectMatterIconographicInterpretation': "Ce portrait n'est pas une commande, empreinte de la réserve de rigueur et rehaussée des symboles de prestige ; il s'agit plutôt d'un portrait d'amis, celui de sa future belle-famille (Auguste-Donat de Hemptinne, son épouse et cousine, Marie-Antoinette de Lathuy et leur fillette de trois ans, Julie), mettant l'accent sur les relations chaleureuses et intimes ainsi que sur les sentiments de tendresse. Si l'on n'y trouve aucune allusion à la profession de pharmacien exercée par Auguste de Hemptinne, par contre son passe-temps, la collection de minéraux et de coquillages attendant un rangement méticuleux dans le médailler, y figure en bonne place  (d'après Dominique Marechal, in 'Musée d'Art Moderne. Oeuvres choisies')",
#    'subjectMatterGeneralSubjectDescription': nan,
#    'subjectMatterSpecificSubjectIdentification': nan}},
#  {'recordID': 129,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'paysage',
#        'children': [{'name': 'plage', 'children': []},
#         {'name': 'mer', 'children': []},
#         {'name': 'bord de mer', 'children': []},
#         {'name': 'ciel', 'children': []},
#         {'name': 'nuage', 'children': []},
#         {'name': 'bateau', 'children': []}]}]},
#     'flattened': ['paysage',
#      'plage',
#      'mer',
#      'bord de mer',
#      'ciel',
#      'nuage',
#      'bateau']},
#    'subjectMatterIconographicTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'Angleterre',
#        'children': [{'name': 'Brighton', 'children': []}]}]},
#     'flattened': ['Angleterre', 'Brighton']},
#    'subjectMatterConceptualTerms': {'tree': {}, 'flattened': []}},
#   'unstructured': {'subjectMatterIconographicInterpretation': "Si les nuages sont caractéristiques de la main du maître, il n'en va pas de même de la facture inachevée de la plage, réalisé par un assistant, peut-être par John Dunthorne, et révélatrice des pratiques d'atelier de Constable. Malgré l'absence de signature, il ne peut y avoir de doute sur l'auteur du ciel nuageux étant donné que le pedigree de l'oeuvre renvoie au fils et petit-fils de Constable lui-même. (d'après Dominique Marechal, in 'Musée d'Art Moderne. Oeuvres choisies')",
#    'subjectMatterGeneralSubjectDescription': 'Vue sur une plage, la mer et un ciel nuageux.',
#    'subjectMatterSpecificSubjectIdentification': "La plage de Hove Beach à l'ouest de Brigthon sur la côte méridionale de l'Angleterre."}},
#  {'recordID': 132,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'scène',
#        'children': [{'name': 'homme', 'children': []},
#         {'name': 'femme', 'children': []},
#         {'name': 'enfant', 'children': []},
#         {'name': 'lutte', 'children': []},
#         {'name': 'combat', 'children': []},
#         {'name': 'drapeau', 'children': []},
#         {'name': 'animal', 'children': [{'name': 'cheval', 'children': []}]},
#         {'name': 'chien', 'children': []},
#         {'name': 'arme', 'children': [{'name': 'lance', 'children': []}]},
#         {'name': 'fusil', 'children': []},
#         {'name': 'sabre', 'children': []},
#         {'name': 'épée', 'children': []},
#         {'name': 'mort', 'children': []},
#         {'name': 'blessé', 'children': []},
#         {'name': 'instrument de musique',
#          'children': [{'name': 'tambour', 'children': []}]}]}]},
#     'flattened': ['scène',
#      'homme',
#      'femme',
#      'enfant',
#      'lutte',
#      'combat',
#      'drapeau',
#      'animal',
#      'cheval',
#      'chien',
#      'arme',
#      'lance',
#      'fusil',
#      'sabre',
#      'épée',
#      'mort',
#      'blessé',
#      'instrument de musique',
#      'tambour']},
#    'subjectMatterIconographicTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'révolution belge', 'children': []},
#       {'name': 'Belgique', 'children': []}]},
#     'flattened': ['révolution belge', 'Belgique']},
#    'subjectMatterConceptualTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'Bruxelles', 'children': []},
#       {'name': 'Grand-place', 'children': []}]},
#     'flattened': ['Bruxelles', 'Grand-place']}},
#   'unstructured': {'subjectMatterIconographicInterpretation': 'Sur commande du nouveau gouvernement de la Belgique, Wappers réalisait, en 1835, son "Episode des journées de septembre 1830", glorifiant la révolution récente et l\'indépendance nouvellement acquise de la jeune nation. Le soir du 25 août 1830, le théâtre de la Monnaie à Bruxelles jouait un opéra d\'Auber, "La muette de Portici" ; au quatrième acte, le chant "Amour sacré de la patrie" déclenchait l\'insurrection qui allait s\'étendre dans le pays. L\'oeuvre de Wappers offre, en composition pyramidale, une synthèse de faits de la révolution et de ses figurants, et met l\'accent sur la diffusion de la proclamation "Aux Citoyens de Bruxelles...", signée le 24 septembre par la Commission administrative représentant l\'autorité belge au coeur de la tourmente (d\'après Brita Velghe, in \'Musée d\'Art Moderne. Oeuvres choisies\')',
#    'subjectMatterGeneralSubjectDescription': "Plusieurs personnages armés, hommes, femmes portent un drapeau ; à l'avant-plan, un mort ; un cavalier ; architecture ; un enfant joue du tambour",
#    'subjectMatterSpecificSubjectIdentification': "Episode des Journées de septembre 1830 sur la Place de l'Hôtel de Ville de Bruxelles"}},
#  {'recordID': 137,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'scène',
#        'children': [{'name': 'homme', 'children': []},
#         {'name': 'femme', 'children': []},
#         {'name': 'enfant',
#          'children': [{'name': 'animal', 'children': []},
#           {'name': 'chameau', 'children': []}]},
#         {'name': 'paysage', 'children': []},
#         {'name': 'désert', 'children': []},
#         {'name': 'tempête', 'children': []},
#         {'name': 'sable', 'children': []},
#         {'name': 'rocher', 'children': []}]}]},
#     'flattened': ['scène',
#      'homme',
#      'femme',
#      'enfant',
#      'animal',
#      'chameau',
#      'paysage',
#      'désert',
#      'tempête',
#      'sable',
#      'rocher']},
#    'subjectMatterIconographicTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'vent',
#        'children': [{'name': 'simoun', 'children': []}]},
#       {'name': 'Afrique', 'children': []},
#       {'name': 'caravane', 'children': []},
#       {'name': 'Syrie', 'children': []}]},
#     'flattened': ['vent', 'simoun', 'Afrique', 'caravane', 'Syrie']},
#    'subjectMatterConceptualTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'Orientalisme', 'children': []}]},
#     'flattened': ['Orientalisme']}},
#   'unstructured': {'subjectMatterIconographicInterpretation': "Après avoir effectué le traditionnel séjour en Italie, Portaels entreprendra des voyages au Maroc, en Algérie, en Egypte, au Liban, en Judée, en Syrie, en Espagne, en Hongrie et en Norvège. Des esquisses et des croquis réalisés sur le motif en Syrie lui serviront de modèles pour l'exécution de peintures représentant un Orient sur lequel s'était posé le regard de l'Occident. (d'après Brita Velghe, in 'Musée d'Art Moderne. Oeuvres choisies')",
#    'subjectMatterGeneralSubjectDescription': "Un groupe de personnages dans un paysage désertique, avec des chameaux ; un nuage de sable s'avance dans le lointain.",
#    'subjectMatterSpecificSubjectIdentification': 'Une caravane surprise par le simoun dans le désert.'}},
#  {'recordID': 138,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'figure',
#        'children': [{'name': 'femme', 'children': []},
#         {'name': 'nu', 'children': []},
#         {'name': 'coiffure', 'children': []},
#         {'name': 'tissu', 'children': [{'name': 'draperie', 'children': []}]},
#         {'name': 'squelette', 'children': []}]}]},
#     'flattened': ['figure',
#      'femme',
#      'nu',
#      'coiffure',
#      'tissu',
#      'draperie',
#      'squelette']},
#    'subjectMatterIconographicTerms': {'tree': {}, 'flattened': []},
#    'subjectMatterConceptualTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'mort', 'children': []},
#       {'name': 'Memento mori', 'children': []},
#       {'name': 'allégorie', 'children': []}]},
#     'flattened': ['mort', 'Memento mori', 'allégorie']}},
#   'unstructured': {'subjectMatterIconographicInterpretation': 'Cette oeuvre emblématique confronte un demi-squelette suspendu, une étiquette portant la mention "La belle / Rosine" sur le crâne, et une jeune fille très dévêtue, une bague au doigt, dont la chevelure est ornée de fleurs et de perles. Les moulages, le chevalet et la palette semblent désigner une banale scène d\'atelier. Mais l\'inscription sur l\'étiquette est explicite : la victoire de la mort, sur la vie et ses vanités transitoires, est inéluctable. "Memento mori" ! Cette allégorie, d\'une paisible fatalité et de moyen format, contraste avec certaines de ses oeuvres habitées par la frénésie et la démesure. (d\'après Brita Velghe, in "Musée d\'Art Moderne. Oeuvres choisies")',
#    'subjectMatterGeneralSubjectDescription': 'Une femme nu en profiel regarde un squelette suspendu.',
#    'subjectMatterSpecificSubjectIdentification': 'La belle Rosine'}},
#  {'recordID': 141,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'groupe',
#        'children': [{'name': 'animal',
#          'children': [{'name': 'cheval', 'children': []}]},
#         {'name': 'homme', 'children': []},
#         {'name': 'femme', 'children': []},
#         {'name': 'être imaginaire', 'children': []}]}]},
#     'flattened': ['groupe',
#      'animal',
#      'cheval',
#      'homme',
#      'femme',
#      'être imaginaire']},
#    'subjectMatterIconographicTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'figures mythologiques',
#        'children': [{'name': 'divinité',
#          'children': [{'name': 'Apollon', 'children': []}]},
#         {'name': 'muse', 'children': []}]}]},
#     'flattened': ['figures mythologiques', 'divinité', 'Apollon', 'muse']},
#    'subjectMatterConceptualTerms': {'tree': {}, 'flattened': []}},
#   'unstructured': {'subjectMatterIconographicInterpretation': nan,
#    'subjectMatterGeneralSubjectDescription': nan,
#    'subjectMatterSpecificSubjectIdentification': nan}},
#  {'recordID': 142,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'scène',
#        'children': [{'name': 'femme', 'children': []},
#         {'name': 'intérieur', 'children': []},
#         {'name': 'fleur', 'children': []},
#         {'name': 'vase', 'children': []},
#         {'name': 'livre', 'children': []},
#         {'name': 'coquillage', 'children': []},
#         {'name': 'table', 'children': []},
#         {'name': 'tapis', 'children': []},
#         {'name': 'bouquet', 'children': []}]}]},
#     'flattened': ['scène',
#      'femme',
#      'intérieur',
#      'fleur',
#      'vase',
#      'livre',
#      'coquillage',
#      'table',
#      'tapis',
#      'bouquet']},
#    'subjectMatterIconographicTerms': {'tree': {}, 'flattened': []},
#    'subjectMatterConceptualTerms': {'tree': {}, 'flattened': []}},
#   'unstructured': {'subjectMatterIconographicInterpretation': 'Porte-flambeau du réalisme en Belgique, Louis Dubois préconisait une totale liberté d\'expression en peinture avec pour seul impératif de mettre "le vrai ton à la vraie place". "La femme au bouquet", une peinture de genre dans laquelle Dubois excellait, présente une rêveuse scène d\'intérieur célébrant, avec une certaine sensualité, la femme et les objets, les matières et les couleurs. (d\'après Brita Velghe, in \'Musée d\'Art Moderne. Oeuvres choisies\')',
#    'subjectMatterGeneralSubjectDescription': "Une femme plaçant diverses fleurs dans un vase. Sur la table recouverte d'un tapis : un autre vase, un livre et un grand coquillage.",
#    'subjectMatterSpecificSubjectIdentification': 'Intérieur'}},
#  {'recordID': 144,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'scène',
#        'children': [{'name': 'homme', 'children': []},
#         {'name': 'femme', 'children': []},
#         {'name': 'enfant', 'children': []},
#         {'name': 'animal', 'children': [{'name': 'chien', 'children': []}]},
#         {'name': 'intérieur', 'children': []},
#         {'name': 'table', 'children': []},
#         {'name': 'banc', 'children': []},
#         {'name': 'couvert', 'children': []},
#         {'name': 'écuelle', 'children': []},
#         {'name': 'cruche', 'children': []},
#         {'name': 'repas', 'children': []},
#         {'name': 'prière', 'children': []}]}]},
#     'flattened': ['scène',
#      'homme',
#      'femme',
#      'enfant',
#      'animal',
#      'chien',
#      'intérieur',
#      'table',
#      'banc',
#      'couvert',
#      'écuelle',
#      'cruche',
#      'repas',
#      'prière']},
#    'subjectMatterIconographicTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'bénédicité', 'children': []}]},
#     'flattened': ['bénédicité']},
#    'subjectMatterConceptualTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'prière', 'children': []},
#       {'name': 'scène biblique',
#        'children': [{'name': 'Cène', 'children': []},
#         {'name': 'Passion', 'children': []},
#         {'name': 'Jésus',
#          'children': [{'name': 'Christ', 'children': []}]}]}]},
#     'flattened': ['prière',
#      'scène biblique',
#      'Cène',
#      'Passion',
#      'Jésus',
#      'Christ']}},
# ...
#      'children': [{'name': 'scène mythologique',
#        'children': [{'name': 'Troie', 'children': []},
#         {'name': 'guerre', 'children': []},
#         {'name': 'Polymnestor', 'children': []},
#         {'name': 'trahison', 'children': []},
#         {'name': 'vengeance', 'children': []},
#         {'name': 'Thrace', 'children': []},
#         {'name': 'Hécube', 'children': []}]}]},
#     'flattened': ['scène mythologique',
#      'Troie',
#      'guerre',
#      'Polymnestor',
#      'trahison',
#      'vengeance',
#      'Thrace',
#      'Hécube']},
#    'subjectMatterConceptualTerms': {'tree': {'name': 'root',
#      'children': [{'name': '[SO] Euripide', 'children': []}]},
#     'flattened': ['[SO] Euripide']}},
#   'unstructured': {'subjectMatterIconographicInterpretation': 'Le thème est probablement emprunté à une tragédie antique d\'Euripide intitulée "Hécube". Pendant la guerre de Troie, la veuve de Priam avait mis en sécurité son plus jeune fils, ainsi qu\'un important trésor, chez son beau-fils Polymnestor, roi de Thrace. Mais celui-ci trahit sa confiance, assassina et dévalisa l\'enfant sans défense qu\'il devait protéger. La toile de Crespi montre Hécube se vengeant de ce crime (d\'après Joost Vander Auwera, in \'Musée d\'Art Ancien. Oeuvres choisies\')',
#    'subjectMatterGeneralSubjectDescription': "Une femme se jette sur un homme maintenu par une autre femme ; de sa main gauche, elle attaque les yeux de l'homme.",
#    'subjectMatterSpecificSubjectIdentification': "Le thème est probablement emprunté à une tragédie antique d'Euripide intitulée Hécube. Pendant la guerre de Troie, la veuve de Priam avait mis en sécurité son plus jeune fils, ainsi qu'un important trésor, chez son beau-fils Polymnestor, roi de Thrace. Mais celui-ci trahit sa confiance, assassina et dévalisa l'enfant sans défense qu'il devait protéger. La toile de Crespi montre Hécube se vengeant de ce crime."}},
#  {'recordID': 2179,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {}, 'flattened': []},
#    'subjectMatterIconographicTerms': {'tree': {}, 'flattened': []},
#    'subjectMatterConceptualTerms': {'tree': {}, 'flattened': []}},
#   'unstructured': {'subjectMatterIconographicInterpretation': nan,
#    'subjectMatterGeneralSubjectDescription': nan,
#    'subjectMatterSpecificSubjectIdentification': nan}},
#  {'recordID': 2180,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'figure',
#        'children': [{'name': 'homme',
#          'children': [{'name': 'en buste', 'children': []},
#           {'name': 'de face', 'children': []}]},
#         {'name': 'couvre-chef', 'children': []}]}]},
#     'flattened': ['figure', 'homme', 'en buste', 'de face', 'couvre-chef']},
#    'subjectMatterIconographicTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'paysan', 'children': []}]},
#     'flattened': ['paysan']},
#    'subjectMatterConceptualTerms': {'tree': {'name': 'root',
#      'children': [{'name': "portrait d'inconnu", 'children': []}]},
#     'flattened': ["portrait d'inconnu"]}},
#   'unstructured': {'subjectMatterIconographicInterpretation': nan,
#    'subjectMatterGeneralSubjectDescription': nan,
#    'subjectMatterSpecificSubjectIdentification': nan}},
#  {'recordID': 2181,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {}, 'flattened': []},
#    'subjectMatterIconographicTerms': {'tree': {}, 'flattened': []},
#    'subjectMatterConceptualTerms': {'tree': {}, 'flattened': []}},
#   'unstructured': {'subjectMatterIconographicInterpretation': nan,
#    'subjectMatterGeneralSubjectDescription': nan,
#    'subjectMatterSpecificSubjectIdentification': nan}},
#  {'recordID': 2182,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {}, 'flattened': []},
#    'subjectMatterIconographicTerms': {'tree': {}, 'flattened': []},
#    'subjectMatterConceptualTerms': {'tree': {}, 'flattened': []}},
#   'unstructured': {'subjectMatterIconographicInterpretation': nan,
#    'subjectMatterGeneralSubjectDescription': nan,
#    'subjectMatterSpecificSubjectIdentification': nan}},
#  {'recordID': 2184,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {}, 'flattened': []},
#    'subjectMatterIconographicTerms': {'tree': {}, 'flattened': []},
#    'subjectMatterConceptualTerms': {'tree': {}, 'flattened': []}},
#   'unstructured': {'subjectMatterIconographicInterpretation': nan,
#    'subjectMatterGeneralSubjectDescription': nan,
#    'subjectMatterSpecificSubjectIdentification': nan}},
#  {'recordID': 2185,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {}, 'flattened': []},
#    'subjectMatterIconographicTerms': {'tree': {}, 'flattened': []},
#    'subjectMatterConceptualTerms': {'tree': {}, 'flattened': []}},
#   'unstructured': {'subjectMatterIconographicInterpretation': nan,
#    'subjectMatterGeneralSubjectDescription': nan,
#    'subjectMatterSpecificSubjectIdentification': nan}},
#  {'recordID': 2187,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'scène',
#        'children': [{'name': 'homme', 'children': []},
#         {'name': 'cavalier', 'children': []},
#         {'name': 'animal', 'children': [{'name': 'cheval', 'children': []}]}]},
#       {'name': 'fond de paysage', 'children': []}]},
#     'flattened': ['scène',
#      'homme',
#      'cavalier',
#      'animal',
#      'cheval',
#      'fond de paysage']},
#    'subjectMatterIconographicTerms': {'tree': {}, 'flattened': []},
#    'subjectMatterConceptualTerms': {'tree': {}, 'flattened': []}},
#   'unstructured': {'subjectMatterIconographicInterpretation': nan,
#    'subjectMatterGeneralSubjectDescription': nan,
#    'subjectMatterSpecificSubjectIdentification': nan}},
#  {'recordID': 2189,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'groupe de figures',
#        'children': [{'name': 'homme',
#          'children': [{'name': 'penché', 'children': []}]},
#         {'name': 'couvre-chef', 'children': []},
#         {'name': 'chapeau', 'children': []},
#         {'name': 'femme', 'children': []},
#         {'name': 'enfant',
#          'children': [{'name': 'nourrisson', 'children': []}]},
#         {'name': 'animal', 'children': [{'name': 'boeuf', 'children': []}]},
#         {'name': 'âne', 'children': []},
#         {'name': 'dromadaire', 'children': []}]}]},
#     'flattened': ['groupe de figures',
#      'homme',
#      'penché',
#      'couvre-chef',
#      'chapeau',
#      'femme',
#      'enfant',
#      'nourrisson',
#      'animal',
#      'boeuf',
#      'âne',
#      'dromadaire']},
#    'subjectMatterIconographicTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'scène biblique',
#        'children': [{'name': '[SO]',
#          'children': [{'name': 'Nouveau Testament', 'children': []},
#           {'name': 'Evangiles', 'children': []},
#           {'name': 'Matthieu', 'children': []},
#           {'name': 'Adoration des Mages', 'children': []}]},
#         {'name': 'Jésus', 'children': [{'name': 'Christ', 'children': []}]},
#         {'name': 'sainte Marie', 'children': []},
#         {'name': 'Vierge', 'children': []},
#         {'name': 'saint Joseph', 'children': []}]}]},
#     'flattened': ['scène biblique',
#      '[SO]',
#      'Nouveau Testament',
#      'Evangiles',
#      'Matthieu',
#      'Adoration des Mages',
#      'Jésus',
#      'Christ',
#      'sainte Marie',
#      'Vierge',
#      'saint Joseph']},
#    'subjectMatterConceptualTerms': {'tree': {}, 'flattened': []}},
#   'unstructured': {'subjectMatterIconographicInterpretation': nan,
#    'subjectMatterGeneralSubjectDescription': nan,
#    'subjectMatterSpecificSubjectIdentification': nan}},
#  {'recordID': 2190,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {}, 'flattened': []},
#    'subjectMatterIconographicTerms': {'tree': {}, 'flattened': []},
#    'subjectMatterConceptualTerms': {'tree': {}, 'flattened': []}},
#   'unstructured': {'subjectMatterIconographicInterpretation': nan,
#    'subjectMatterGeneralSubjectDescription': nan,
#    'subjectMatterSpecificSubjectIdentification': nan}},
#  {'recordID': 2191,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'groupe de figures',
#        'children': [{'name': 'homme',
#          'children': [{'name': 'assis', 'children': []}]},
#         {'name': 'vêtement', 'children': [{'name': 'habit', 'children': []}]},
#         {'name': 'chapeau', 'children': []},
#         {'name': 'bâton', 'children': []},
#         {'name': 'pipe', 'children': []}]},
#       {'name': 'intérieur', 'children': []},
#       {'name': 'bois', 'children': []},
#       {'name': 'banc', 'children': []},
#       {'name': 'tonneau', 'children': []},
#       {'name': 'charrette', 'children': []},
#       {'name': 'paille', 'children': []}]},
#     'flattened': ['groupe de figures',
#      'homme',
#      'assis',
#      'vêtement',
#      'habit',
#      'chapeau',
#      'bâton',
#      'pipe',
#      'intérieur',
#      'bois',
#      'banc',
#      'tonneau',
#      'charrette',
#      'paille']},
#    'subjectMatterIconographicTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'scène',
#        'children': [{'name': 'jeu de cartes', 'children': []}]}]},
#     'flattened': ['scène', 'jeu de cartes']},
#    'subjectMatterConceptualTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'effet de lumière', 'children': []}]},
#     'flattened': ['effet de lumière']}},
#   'unstructured': {'subjectMatterIconographicInterpretation': nan,
#    'subjectMatterGeneralSubjectDescription': nan,
#    'subjectMatterSpecificSubjectIdentification': nan}},
#  {'recordID': 2192,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {}, 'flattened': []},
#    'subjectMatterIconographicTerms': {'tree': {}, 'flattened': []},
#    'subjectMatterConceptualTerms': {'tree': {}, 'flattened': []}},
#   'unstructured': {'subjectMatterIconographicInterpretation': nan,
#    'subjectMatterGeneralSubjectDescription': nan,
#    'subjectMatterSpecificSubjectIdentification': nan}},
#  {'recordID': 2193,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'figure',
#        'children': [{'name': 'homme',
#          'children': [{'name': 'à mi-corps', 'children': []}]},
#         {'name': 'vêtement', 'children': [{'name': 'col', 'children': []}]},
#         {'name': 'plan', 'children': []},
#         {'name': 'boussole', 'children': []}]}]},
#     'flattened': ['figure',
#      'homme',
#      'à mi-corps',
#      'vêtement',
#      'col',
#      'plan',
#      'boussole']},
#    'subjectMatterIconographicTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'portrait',
#        'children': [{'name': 'Cornelis Danckerts de Rij', 'children': []},
#         {'name': 'architecte', 'children': []},
#         {'name': 'artiste',
#          'children': [{'name': 'sculpteur', 'children': []}]}]}]},
#     'flattened': ['portrait',
#      'Cornelis Danckerts de Rij',
#      'architecte',
#      'artiste',
#      'sculpteur']},
#    'subjectMatterConceptualTerms': {'tree': {}, 'flattened': []}},
#   'unstructured': {'subjectMatterIconographicInterpretation': nan,
#    'subjectMatterGeneralSubjectDescription': nan,
#    'subjectMatterSpecificSubjectIdentification': nan}},
#  {'recordID': 2194,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'figure',
#        'children': [{'name': 'femme',
#          'children': [{'name': 'assis', 'children': []},
#           {'name': 'vieille', 'children': []}]},
#         {'name': 'col', 'children': []},
#         {'name': 'coiffe', 'children': []},
#         {'name': 'lunettes', 'children': []},
#         {'name': 'bijou', 'children': [{'name': 'anneau', 'children': []}]},
#         {'name': 'livre', 'children': []}]},
#       {'name': 'chaise', 'children': []},
#       {'name': 'pilier', 'children': []}]},
#     'flattened': ['figure',
#      'femme',
#      'assis',
#      'vieille',
#      'col',
#      'coiffe',
#      'lunettes',
#      'bijou',
#      'anneau',
#      'livre',
#      'chaise',
#      'pilier']},
#    'subjectMatterIconographicTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'portrait',
#        'children': [{'name': 'Oede Seyle', 'children': []}]}]},
#     'flattened': ['portrait', 'Oede Seyle']},
#    'subjectMatterConceptualTerms': {'tree': {}, 'flattened': []}},
#   'unstructured': {'subjectMatterIconographicInterpretation': nan,
#    'subjectMatterGeneralSubjectDescription': nan,
#    'subjectMatterSpecificSubjectIdentification': nan}},
#  {'recordID': 2197,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'groupe de figures',
#        'children': [{'name': 'homme', 'children': []},
#         {'name': 'femme', 'children': []},
#         {'name': 'enfant', 'children': []},
#         {'name': 'foule', 'children': []},
#         {'name': 'vêtement', 'children': []},
#         {'name': 'habit', 'children': []},
#         {'name': 'robe', 'children': []},
#         {'name': 'chapeau', 'children': []},
#         {'name': 'coiffure', 'children': []},
#         {'name': 'chapelet',
#          'children': [{'name': 'rosaire', 'children': []}]},
#         {'name': 'bâton', 'children': []}]},
#       {'name': 'intérieur',
#        'children': [{'name': 'pavement', 'children': []},
#         {'name': 'vitrail', 'children': []},
#         {'name': 'meuble', 'children': [{'name': 'banc', 'children': []}]},
#         {'name': 'tableau', 'children': []},
#         {'name': "élément d'architecture",
#          'children': [{'name': 'colonne', 'children': []}]},
#         {'name': 'tombeau',
#          'children': [{'name': 'pierre', 'children': []}]}]}]},
#     'flattened': ['groupe de figures',
#      'homme',
#      'femme',
#      'enfant',
#      'foule',
#      'vêtement',
#      'habit',
#      'robe',
#      'chapeau',
#      'coiffure',
#      'chapelet',
#      'rosaire',
#      'bâton',
#      'intérieur',
#      'pavement',
#      'vitrail',
#      'meuble',
#      'banc',
#      'tableau',
#      "élément d'architecture",
#      'colonne',
#      'tombeau',
#      'pierre']},
#    'subjectMatterIconographicTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'scène religieuse',
#        'children': [{'name': 'prière', 'children': []},
#         {'name': 'église', 'children': []},
#         {'name': 'messe', 'children': []}]},
#       {'name': 'pauvreté', 'children': []}]},
#     'flattened': ['scène religieuse',
#      'prière',
#      'église',
#      'messe',
#      'pauvreté']},
#    'subjectMatterConceptualTerms': {'tree': {'name': 'root',
#      'children': [{'name': 'effet de lumière', 'children': []}]},
#     'flattened': ['effet de lumière']}},
#   'unstructured': {'subjectMatterIconographicInterpretation': '« Le banc des pauvres » fait partie des premiers exemples de manifestation de la compassion de De Groux envers la classe ouvrière et paysanne, avec laquelle il partage la vision de fatalisme pessimiste. Un groupe de pauvres, cherchant une consolation dans le monde meilleur promis par la piété religieuse, occupe l\'avant-plan du tableau, traité en grandes dimensions, dans un cadre cintré évoquant la peinture religieuse des retables d\'autels. Isolés de la foule de bourgeois qui occupe la nef centrale attentive à la liturgie en latin, les attitudes des pauvres expriment la désolation, la supplication, la résignation ou même l\'ennui. La sensibilité chromatique et la lumière bien étudiée de l\'oeuvre de De Groux renforcent le pathétique de la scène (d\'après Véronique Coomans-Cardon, in cat. "Le Romantisme en Belgique"). "Le banc des pauvres", dans la version aquarellée précédant ce tableau (inv. 11527), exprime plus pauvreté et abandon que cette toile (d\'après Anne Adriaens-Pannier, in cat. "Le Romantisme en Belgique")',
#    'subjectMatterGeneralSubjectDescription': nan,
#    'subjectMatterSpecificSubjectIdentification': nan}},
#  {'recordID': 2198,
#   'structured': {'subjectMatterSubjectTerms': {'tree': {}, 'flattened': []},
#    'subjectMatterIconographicTerms': {'tree': {}, 'flattened': []},
#    'subjectMatterConceptualTerms': {'tree': {}, 'flattened': []}},
#   'unstructured': {'subjectMatterIconographicInterpretation': nan,
#    'subjectMatterGeneralSubjectDescription': nan,
#    'subjectMatterSpecificSubjectIdentification': nan}},
#  ...]

# %% [markdown]
# # 1) Insert the captions generated by moondream

# %%
def fixPadding(caption):
    if "." in caption:
        caption = caption.split(".")[0].strip()
    else:
        caption = caption.strip()

    while ".." in caption:
        caption = caption.replace("..", ".")
    while "''" in caption:
        caption = caption.replace("''", "'")
        
    return caption

index = 50
EN_caption = moondream_captions.iloc[index]["EN"]
FR_caption = moondream_captions.iloc[index]["FR"]
FR_caption = fixPadding(FR_caption)

print(EN_caption)
print(FR_caption)
# Out:
#  A young girl in a white dress with a fur-trimmed cape and a white bonnet sits on a wooden bench, framed by an ornate gold frame.
# Une jeune fille vêtue d'une robe blanche avec une cape en fourrure et un capot blanc est assise sur un banc en bois, encadrée d'un cadre en or ornithologiquement ornée d'un cadre en forme de tête

# %%
moondream_captions[LANG].head(10).apply(fixPadding)
# Out:
# 0    Une scène religieuse présente une figure centr...
# 1    À l'image, il y a deux personnes sur une croix...
# 2    L'image présente une peinture avec un schéma d...
# 3                                   L'image est sombre
# 4    En regardant cette image, je ressens un sentim...
# 5    Une femme en robe rouge, assise sur un banc, r...
# 6    Dans l'image, il y a une femme assise sur un b...
# 7    Les couleurs que je vois dans l'image sont rou...
# 8                                L'image est lumineuse
# 9    En regardant cette image, je sens un sentiment...
# Name: FR, dtype: object

# %%
"""
    "record_id",
    "row_type",
    "caption",
    "number_of_tokens"
"""
N = len(moondream_captions)
record_ids = list(moondream_captions["recordID"])
row_type = []
caption = list(moondream_captions[LANG].apply(fixPadding))
number_of_tokens = []
for i in tqdm(range(N)):
    number_of_tokens.append(len(tokenizer.encode(caption[i])))
    task = moondream_captions["task"][i]
    row_type.append(f"synthetic_caption:{task}")

# Insert the captions into the training dataset
new_rows = pd.DataFrame({
    "record_id": record_ids,
    "row_type": row_type,
    "caption": caption,
    "number_of_tokens": number_of_tokens
})

training_dataset = pd.concat([training_dataset, new_rows], ignore_index=True)

training_dataset
# Out:
#   0%|          | 0/26505 [00:00<?, ?it/s]Token indices sequence length is longer than the specified maximum sequence length for this model (83 > 77). Running this sequence through the model will result in indexing errors
# 100%|██████████| 26505/26505 [00:03<00:00, 7927.33it/s]
#       record_id                                           row_type  \
# 0            64                          synthetic_caption:caption
# 1            64        synthetic_caption:What objects do you see ?
# 2            64         synthetic_caption:What colors do you see ?
# 3            64   synthetic_caption:Is this image bright or dark ?
# 4            64  synthetic_caption:What emotion do you feel whe...
# ...         ...                                                ...
# 26500     13380                          synthetic_caption:caption
# 26501     13380        synthetic_caption:What objects do you see ?
# 26502     13380         synthetic_caption:What colors do you see ?
# 26503     13380   synthetic_caption:Is this image bright or dark ?
# 26504     13380  synthetic_caption:What emotion do you feel whe...
#
#                                                  caption number_of_tokens
# 0      Une scène religieuse présente une figure centr...               56
# 1      À l'image, il y a deux personnes sur une croix...               34
# 2      L'image présente une peinture avec un schéma d...               28
# 3                                     L'image est sombre                8
# 4      En regardant cette image, je ressens un sentim...               23
# ...                                                  ...              ...
# 26500  Une gravure en noir et blanc, signée "Giorgos ...               53
# 26501  À l'image, il y a deux personnes, un homme et ...               37
# 26502                L'image est un dessin noir et blanc               12
# 26503                                 L'image est sombre                8
# 26504  En regardant cette image, je ressens un sentim...               29
#
# [26505 rows x 4 columns]

# %%
def analyze_captions(training_dataset):
    # Recompute the number of tokens
    training_dataset["number_of_tokens"] = training_dataset["caption"].apply(lambda x: len(tokenizer.encode(x)))

    # Histogram of the number of tokens in function of the row type
    training_dataset["number_of_tokens"].hist(by=training_dataset["row_type"], bins=100, figsize=(10, 10))
    plt.show()

    # Table of the number of captions per row type having <= 77 tokens
    table_respecting_clip_limit = pd.DataFrame(columns=[
        "row_type", 
        "<= TOKEN_LIMIT tokens", 
        "> TOKEN_LIMIT tokens", 
        "% <= TOKEN_LIMIT tokens",
        "% > TOKEN_LIMIT tokens",
        "Average overflow"
    ])

    for row_type in training_dataset["row_type"].unique():
        
        rows = training_dataset[training_dataset["row_type"] == row_type]
        N = len(rows)

        rows_overflowing_clip_limit = rows[rows["number_of_tokens"] > TOKEN_LIMIT]
        rows_respecting_clip_limit = rows[rows["number_of_tokens"] <= TOKEN_LIMIT]

        N_respecting_clip_limit = len(rows_respecting_clip_limit)
        N_not_respecting_clip_limit = len(rows_overflowing_clip_limit)
        percentage_respecting_clip_limit = round((N_respecting_clip_limit / N) * 100, 2)
        percentage_not_respecting_clip_limit = round((N_not_respecting_clip_limit / N) * 100, 2)

        average_overflow = round(rows_overflowing_clip_limit["number_of_tokens"].mean() - TOKEN_LIMIT, 2)
        
        table_respecting_clip_limit.loc[len(table_respecting_clip_limit)] = [
            row_type,
            N_respecting_clip_limit,
            N_not_respecting_clip_limit,
            percentage_respecting_clip_limit,
            percentage_not_respecting_clip_limit,
            average_overflow
        ]

    # Order the table by the percentage of captions having > TOKEN_LIMIT tokens
    table_respecting_clip_limit = table_respecting_clip_limit.sort_values(by="% > TOKEN_LIMIT tokens", ascending=False)

    return table_respecting_clip_limit

analyze_captions(training_dataset)
# Out:
#                                             row_type  <= TOKEN_LIMIT tokens  \
# 0                          synthetic_caption:caption                   5271
# 1        synthetic_caption:What objects do you see ?                   5299
# 2         synthetic_caption:What colors do you see ?                   5299
# 4  synthetic_caption:What emotion do you feel whe...                   5299
# 3   synthetic_caption:Is this image bright or dark ?                   5301
#
#    > TOKEN_LIMIT tokens  % <= TOKEN_LIMIT tokens  % > TOKEN_LIMIT tokens  \
# 0                    30                    99.43                    0.57
# 1                     2                    99.96                    0.04
# 2                     2                    99.96                    0.04
# 4                     2                    99.96                    0.04
# 3                     0                   100.00                    0.00
#
#    Average overflow
# 0              25.2
# 1              46.0
# 2              31.0
# 4              11.0
# 3               NaN

# %% [markdown]
# #### The answers to the questions (except the questions regarding the brightness of the image) are clearly too long ! Lets analyze them !
# I chose to just select the first sentence ! This solved this issue !
# Below is my previous technic !

# %%
if False:
    from collections import Counter

    def get_redundant_words(captions, percentage_most_common):
        # Flatten all words into a single list
        all_words = " ".join(captions).lower().split()
        
        # Count word occurrences
        word_counts = Counter(all_words)
        
        # Get the most common words (percentage-based)
        num_words_to_remove = int(len(word_counts) * percentage_most_common)
        most_common_words = {word for word, _ in word_counts.most_common(num_words_to_remove)}
        
        return most_common_words

    # Test
    words = get_redundant_words(training_dataset["caption"], 0.005)
    print(words)

    # Sadly there are words that I would consider as interesting that are removed !
    # I will have to find a way to keep them while removing the most common words

    common_unnecessary_words_fr = {
        "un", "une", "le", "la", "les", "de", "du", "des", "à", "en", "dans", "sur", "sous",
        "avec", "sans", "pour", "par", "et", "ou", "mais", "donc", "or", "ni", "car",
        "est", "sont", "était", "étaient", "être", "été", "ayant", "avoir", "a", "as", "ai", "avons", 
        "avez", "ont", "avait", "avaient", "au", "aux", "ce", "cet", "cette", "ces", 
        "celui", "celle", "ceux", "celles", "lui", "elle", "eux", "elles", "il", "ils", "on", "nous",
        "vous", "mon", "ton", "son", "ma", "ta", "sa", "mes", "tes", "ses", "notre", "votre", "leur",
        "leurs", "quel", "quelle", "quels", "quelles", "quoi", "dont", "où", "comment", "quand",
        "avant", "après", "pendant", "depuis", "trop", "très", "peu", "beaucoup", "plus", "moins",
        "aussi", "ainsi", "alors", "comme", "si", "car", "que", "qui", "qu'", "quoi", "lorsque",
        "tant", "tel", "tels", "telle", "telles", "certains", "certaines", "chaque", "autre", "autres",
        "tous", "tout", "toute", "toutes", "encore", "déjà", "seulement", "même", "mêmes",
        "aucun", "aucune", "nul", "nulle", "rien", "personne", 
        
        "image", "L'image", "présente", "représente", "montre", "représente", "illustre", "illustre",
        "l'image", "y", "je", "tu", "il", "elle", "on", "nous", "vous", "ils", "elles", "ce", "cette", "ces",
        "vois"
    }
    symbols_to_remove = {
        ",", ".", "!", "?", "...", "''", "'''"
    }


    def remove_redundant_words(captions, words_to_remove):
        simplified_captions = []
        for caption in captions:
            simplified_caption = " ".join([word for word in caption.split() if word.lower() not in words_to_remove])
            simplified_caption = "".join([char for char in simplified_caption if char not in symbols_to_remove])
            simplified_captions.append(simplified_caption)
        
        return simplified_captions
    training_dataset["caption"] = remove_redundant_words(training_dataset["caption"], common_unnecessary_words_fr)
    analyze_captions(training_dataset)

    unique_row_types = training_dataset["row_type"].unique()
    head_size = 3
    for row_type in unique_row_types:
        print(row_type)
        for caption in training_dataset[training_dataset["row_type"] == row_type]["caption"].head(head_size):
            print(caption + "\n")
        print("\n")

# %%
print(f"Using only moondream captions, we have {len(training_dataset)} captions")
# Out:
# Using only moondream captions, we have 26505 captions

# %% [markdown]
# # 2) Insert the captions generated using the subject matter

# %%
def isFull(subjectmatter_caption):
    structured = subjectmatter_caption["structured"]
    unstructured = subjectmatter_caption["unstructured"]
    for key in structured.keys():
        #Check if the flat is not empty
        if len(structured[key]["flattened"]) == 0 or structured[key]["flattened"] is np.nan:
            return False
    for key in unstructured.keys():
        if pd.isna(unstructured[key]):
            return False
    return True

index = 0
while not isFull(subjectmatter_json[index]):
    index += 1

example_subjectmatter = subjectmatter_json[index]
example_subjectmatter
# Out:
# {'recordID': 119,
#  'structured': {'subjectMatterSubjectTerms': {'tree': {'name': 'root',
#     'children': [{'name': 'figure',
#       'children': [{'name': 'homme',
#         'children': [{'name': 'nu', 'children': []}]},
#        {'name': 'mort', 'children': []},
#        {'name': 'arme', 'children': [{'name': 'couteau', 'children': []}]},
#        {'name': 'sang', 'children': []},
#        {'name': 'lettre', 'children': []},
#        {'name': "instrument d'écriture",
#         'children': [{'name': 'plume', 'children': []}]},
#        {'name': 'encrier', 'children': []}]},
#      {'name': 'scène', 'children': [{'name': 'bain', 'children': []}]}]},
#    'flattened': ['figure',
#     'homme',
#     'nu',
#     'mort',
#     'arme',
#     'couteau',
#     'sang',
#     'lettre',
#     "instrument d'écriture",
#     'plume',
#     'encrier',
#     'scène',
#     'bain']},
#   'subjectMatterIconographicTerms': {'tree': {'name': 'root',
#     'children': [{'name': 'portrait',
#       'children': [{'name': 'Jean Paul Marat', 'children': []}]},
#      {'name': 'meurtre', 'children': []},
#      {'name': 'révolution française', 'children': []}]},
#    'flattened': ['portrait',
#     'Jean Paul Marat',
#     'meurtre',
#     'révolution française']},
#   'subjectMatterConceptualTerms': {'tree': {'name': 'root',
#     'children': [{'name': 'martyre', 'children': []},
#      {'name': 'Marie-Anne Charlotte Corday', 'children': []},
#      {'name': 'Louis XVI', 'children': []}]},
#    'flattened': ['martyre', 'Marie-Anne Charlotte Corday', 'Louis XVI']}},
#  'unstructured': {'subjectMatterIconographicInterpretation': 'Le 13 juillet 1793 Marie-Anne Charlotte Corday, partisane des Girondins, se fit introduire auprès de Marat, sous prétexte de lui communiquer des renseignements sur ceux-ci et le poignarda. Marat, qui souffrait d\'une maladie de la peau que seuls des bains soulageaient, travaillait souvent dans sa baignoire. Il publiait depuis 1789 le journal "L\'ami du peuple" : il tient encore son "arme", la plume, en main, représentée ici tout près de l\'arme encore ensanglantée du crime. On demanda à David d\'organiser la pompe des funérailles et de peindre un tableau commémoratif. De la mythologie classique qui jusqu\'alors constituait sa galerie de modèles, David passe ici à un héros de l\'histoire contemporaine. Il idéalise son héros en s\'en tenant à un strict réalisme. Le peintre est à ce moment l\'artiste français le plus en vue mais aussi un ami personnel de la victime ; tous deux ont voté, à la Convention, la mort de Louis XVI. (d\'après Frederik Leen, in \'Musée d\'Art Moderne. Oeuvres choisies\')',
#   'subjectMatterGeneralSubjectDescription': 'Un homme avec une blessure à la poitrine gît, mort, dans une baignoire ; il tient une plume et une lettre ; sur une table sont posés une autre plume et un encrier ; sur le sol, un couteau ensanglanté.',
#   'subjectMatterSpecificSubjectIdentification': 'Marat assassiné'}}

# %%
def get_caption_from__subjectMatterSubjectTerms(subjectMatterSubjectTerms):
    if len(subjectMatterSubjectTerms) == 0:
        return None
    else:
        return " ".join(subjectMatterSubjectTerms)

get_caption_from__subjectMatterSubjectTerms(example_subjectmatter["structured"]["subjectMatterSubjectTerms"]["flattened"])
# Out:
# "figure homme nu mort arme couteau sang lettre instrument d'écriture plume encrier scène bain"

# %%
def get_caption_from__subjectMatterIconographicTerms(subjectMatterIconographicTerms):
    if len(subjectMatterIconographicTerms) == 0:
        return None
    else:
        return " ".join(subjectMatterIconographicTerms)

get_caption_from__subjectMatterIconographicTerms(example_subjectmatter["structured"]["subjectMatterIconographicTerms"]["flattened"])
# Out:
# 'portrait Jean Paul Marat meurtre révolution française'

# %%
def get_caption_from__subjectMatterConceptualTerms(subjectMatterConceptualTerms):
    if len(subjectMatterConceptualTerms) == 0:
        return None
    else:
        return " ".join(subjectMatterConceptualTerms)

get_caption_from__subjectMatterConceptualTerms(example_subjectmatter["structured"]["subjectMatterConceptualTerms"]["flattened"])
# Out:
# 'martyre Marie-Anne Charlotte Corday Louis XVI'

# %%
def get_caption_from__subjectMatterIconographicInterpretation(subjectMatterIconographicInterpretation):
    if pd.isna(subjectMatterIconographicInterpretation):
        return None
    else:
        return subjectMatterIconographicInterpretation

get_caption_from__subjectMatterIconographicInterpretation(example_subjectmatter["unstructured"]["subjectMatterIconographicInterpretation"])
# Out:
# 'Le 13 juillet 1793 Marie-Anne Charlotte Corday, partisane des Girondins, se fit introduire auprès de Marat, sous prétexte de lui communiquer des renseignements sur ceux-ci et le poignarda. Marat, qui souffrait d\'une maladie de la peau que seuls des bains soulageaient, travaillait souvent dans sa baignoire. Il publiait depuis 1789 le journal "L\'ami du peuple" : il tient encore son "arme", la plume, en main, représentée ici tout près de l\'arme encore ensanglantée du crime. On demanda à David d\'organiser la pompe des funérailles et de peindre un tableau commémoratif. De la mythologie classique qui jusqu\'alors constituait sa galerie de modèles, David passe ici à un héros de l\'histoire contemporaine. Il idéalise son héros en s\'en tenant à un strict réalisme. Le peintre est à ce moment l\'artiste français le plus en vue mais aussi un ami personnel de la victime ; tous deux ont voté, à la Convention, la mort de Louis XVI. (d\'après Frederik Leen, in \'Musée d\'Art Moderne. Oeuvres choisies\')'

# %%
def get_caption_from__subjectMatterGeneralSubjectDescription(subjectMatterGeneralSubjectDescription):
    if pd.isna(subjectMatterGeneralSubjectDescription):
        return None
    else:
        return subjectMatterGeneralSubjectDescription

get_caption_from__subjectMatterGeneralSubjectDescription(example_subjectmatter["unstructured"]["subjectMatterGeneralSubjectDescription"])
# Out:
# 'Un homme avec une blessure à la poitrine gît, mort, dans une baignoire ; il tient une plume et une lettre ; sur une table sont posés une autre plume et un encrier ; sur le sol, un couteau ensanglanté.'

# %%
def get_caption_from__subjectMatterSpecificSubjectIdentification(subjectMatterSpecificSubjectIdentification):
    if pd.isna(subjectMatterSpecificSubjectIdentification):
        return None
    else:
        return subjectMatterSpecificSubjectIdentification

get_caption_from__subjectMatterSpecificSubjectIdentification(example_subjectmatter["unstructured"]["subjectMatterSpecificSubjectIdentification"])
# Out:
# 'Marat assassiné'

# %%
subject_matter_captions = pd.DataFrame(columns=["record_id", "row_type", "caption", "number_of_tokens"])

for subjectmatter in tqdm(subjectmatter_json):
    record_id = subjectmatter["recordID"]
    
    # subjectMatterSubjectTerms
    subjectMatterSubjectTerms = get_caption_from__subjectMatterSubjectTerms(subjectmatter["structured"]["subjectMatterSubjectTerms"]["flattened"])
    if subjectMatterSubjectTerms is not None:
        row_type = "subjectMatterSubjectTerms"
        caption = subjectMatterSubjectTerms
        number_of_tokens = len(tokenizer.encode(caption))
        subject_matter_captions.loc[len(subject_matter_captions)] = [record_id, row_type, caption, number_of_tokens]

    # subjectMatterIconographicTerms
    subjectMatterIconographicTerms = get_caption_from__subjectMatterIconographicTerms(subjectmatter["structured"]["subjectMatterIconographicTerms"]["flattened"])
    if subjectMatterIconographicTerms is not None:
        row_type = "subjectMatterIconographicTerms"
        caption = subjectMatterIconographicTerms
        number_of_tokens = len(tokenizer.encode(caption))
        subject_matter_captions.loc[len(subject_matter_captions)] = [record_id, row_type, caption, number_of_tokens]

    # subjectMatterConceptualTerms
    subjectMatterConceptualTerms = get_caption_from__subjectMatterConceptualTerms(subjectmatter["structured"]["subjectMatterConceptualTerms"]["flattened"])
    if subjectMatterConceptualTerms is not None:
        row_type = "subjectMatterConceptualTerms"
        caption = subjectMatterConceptualTerms
        number_of_tokens = len(tokenizer.encode(caption))
        subject_matter_captions.loc[len(subject_matter_captions)] = [record_id, row_type, caption, number_of_tokens]

    # subjectMatterIconographicInterpretation
    subjectMatterIconographicInterpretation = get_caption_from__subjectMatterIconographicInterpretation(subjectmatter["unstructured"]["subjectMatterIconographicInterpretation"])
    if subjectMatterIconographicInterpretation is not None:
        row_type = "subjectMatterIconographicInterpretation"
        caption = subjectMatterIconographicInterpretation
        number_of_tokens = len(tokenizer.encode(caption))
        subject_matter_captions.loc[len(subject_matter_captions)] = [record_id, row_type, caption, number_of_tokens]

    # subjectMatterGeneralSubjectDescription
    subjectMatterGeneralSubjectDescription = get_caption_from__subjectMatterGeneralSubjectDescription(subjectmatter["unstructured"]["subjectMatterGeneralSubjectDescription"])
    if subjectMatterGeneralSubjectDescription is not None:
        row_type = "subjectMatterGeneralSubjectDescription"
        caption = subjectMatterGeneralSubjectDescription
        number_of_tokens = len(tokenizer.encode(caption))
        subject_matter_captions.loc[len(subject_matter_captions)] = [record_id, row_type, caption, number_of_tokens]

    # subjectMatterSpecificSubjectIdentification
    subjectMatterSpecificSubjectIdentification = get_caption_from__subjectMatterSpecificSubjectIdentification(subjectmatter["unstructured"]["subjectMatterSpecificSubjectIdentification"])
    if subjectMatterSpecificSubjectIdentification is not None:
        row_type = "subjectMatterSpecificSubjectIdentification"
        caption = subjectMatterSpecificSubjectIdentification
        number_of_tokens = len(tokenizer.encode(caption))
        subject_matter_captions.loc[len(subject_matter_captions)] = [record_id, row_type, caption, number_of_tokens]


subject_matter_captions
# Out:
# 100%|██████████| 5301/5301 [00:05<00:00, 949.66it/s]
#       record_id                        row_type  \
# 0            64       subjectMatterSubjectTerms
# 1            64  subjectMatterIconographicTerms
# 2            77       subjectMatterSubjectTerms
# 3            78       subjectMatterSubjectTerms
# 4            78  subjectMatterIconographicTerms
# ...         ...                             ...
# 7856      11645       subjectMatterSubjectTerms
# 7857      11646       subjectMatterSubjectTerms
# 7858      11805       subjectMatterSubjectTerms
# 7859      11805  subjectMatterIconographicTerms
# 7860      11805    subjectMatterConceptualTerms
#
#                                                 caption  number_of_tokens
# 0     scène homme femme enfant vêtement habit robe c...                52
# 1     scène biblique [SO] Nouveau Testament Evangile...                34
# 2                       figure femme arbre table chaise                 9
# 3     figure enfant de face robe noeud intérieur chaise                17
# 4                portrait fillette Louise van der Hecht                10
# ...                                                 ...               ...
# 7856         figure femme en buste vêtement robe coiffe                15
# 7857                        figure homme en buste habit                 8
# 7858   groupe de figures ouvrier bâtiment voûte machine                17
# 7859                                      scène travail                 7
# 7860                            industrie métallurgique                 9
#
# [7861 rows x 4 columns]

# %%
analyze_captions(subject_matter_captions)
# Out:
#                                      row_type  <= TOKEN_LIMIT tokens  \
# 2     subjectMatterIconographicInterpretation                     21
# 4      subjectMatterGeneralSubjectDescription                     92
# 5  subjectMatterSpecificSubjectIdentification                    106
# 0                   subjectMatterSubjectTerms                   3581
# 1              subjectMatterIconographicTerms                   2809
# 3                subjectMatterConceptualTerms                    670
#
#    > TOKEN_LIMIT tokens  % <= TOKEN_LIMIT tokens  % > TOKEN_LIMIT tokens  \
# 2                   495                     4.07                   95.93
# 4                    31                    74.80                   25.20
# 5                    19                    84.80                   15.20
# 0                    29                    99.20                    0.80
# 1                     8                    99.72                    0.28
# 3                     0                   100.00                    0.00
#
#    Average overflow
# 2            214.84
# 4             38.77
# 5             66.05
# 0             20.41
# 1             22.38
# 3               NaN

# %% [markdown]
# # 3) Compile both training datasets

# %%
full_training_dataset = pd.concat([training_dataset, subject_matter_captions], ignore_index=True)
full_training_dataset
# Out:
#       record_id                                           row_type  \
# 0            64                          synthetic_caption:caption
# 1            64        synthetic_caption:What objects do you see ?
# 2            64         synthetic_caption:What colors do you see ?
# 3            64   synthetic_caption:Is this image bright or dark ?
# 4            64  synthetic_caption:What emotion do you feel whe...
# ...         ...                                                ...
# 34361     11645                          subjectMatterSubjectTerms
# 34362     11646                          subjectMatterSubjectTerms
# 34363     11805                          subjectMatterSubjectTerms
# 34364     11805                     subjectMatterIconographicTerms
# 34365     11805                       subjectMatterConceptualTerms
#
#                                                  caption  number_of_tokens
# 0      Une scène religieuse présente une figure centr...                56
# 1      À l'image, il y a deux personnes sur une croix...                34
# 2      L'image présente une peinture avec un schéma d...                28
# 3                                     L'image est sombre                 8
# 4      En regardant cette image, je ressens un sentim...                23
# ...                                                  ...               ...
# 34361         figure femme en buste vêtement robe coiffe                15
# 34362                        figure homme en buste habit                 8
# 34363   groupe de figures ouvrier bâtiment voûte machine                17
# 34364                                      scène travail                 7
# 34365                            industrie métallurgique                 9
#
# [34366 rows x 4 columns]

# %%
analyze_captions(full_training_dataset)
# Out:
#                                              row_type  <= TOKEN_LIMIT tokens  \
# 7             subjectMatterIconographicInterpretation                     21
# 9              subjectMatterGeneralSubjectDescription                     92
# 10         subjectMatterSpecificSubjectIdentification                    106
# 5                           subjectMatterSubjectTerms                   3581
# 0                           synthetic_caption:caption                   5271
# 6                      subjectMatterIconographicTerms                   2809
# 1         synthetic_caption:What objects do you see ?                   5299
# 2          synthetic_caption:What colors do you see ?                   5299
# 4   synthetic_caption:What emotion do you feel whe...                   5299
# 3    synthetic_caption:Is this image bright or dark ?                   5301
# 8                        subjectMatterConceptualTerms                    670
#
#     > TOKEN_LIMIT tokens  % <= TOKEN_LIMIT tokens  % > TOKEN_LIMIT tokens  \
# 7                    495                     4.07                   95.93
# 9                     31                    74.80                   25.20
# 10                    19                    84.80                   15.20
# 5                     29                    99.20                    0.80
# 0                     30                    99.43                    0.57
# 6                      8                    99.72                    0.28
# 1                      2                    99.96                    0.04
# 2                      2                    99.96                    0.04
# 4                      2                    99.96                    0.04
# 3                      0                   100.00                    0.00
# 8                      0                   100.00                    0.00
#
#     Average overflow
# 7             214.84
# 9              38.77
# 10             66.05
# 5              20.41
# 0              25.20
# 6              22.38
# 1              46.00
# 2              31.00
# 4              11.00
# 3                NaN
# 8                NaN

# %% [markdown]
# # 4) Clean the full dataset so that it only contains short enough captions

# %%
# We allow a 10 tokens overflow, the truncation will take care of it
clean_full_training_dataset = full_training_dataset[full_training_dataset["number_of_tokens"] <= TOKEN_LIMIT + 10]
clean_full_training_dataset
# Out:
#       record_id                                           row_type  \
# 0            64                          synthetic_caption:caption
# 1            64        synthetic_caption:What objects do you see ?
# 2            64         synthetic_caption:What colors do you see ?
# 3            64   synthetic_caption:Is this image bright or dark ?
# 4            64  synthetic_caption:What emotion do you feel whe...
# ...         ...                                                ...
# 34361     11645                          subjectMatterSubjectTerms
# 34362     11646                          subjectMatterSubjectTerms
# 34363     11805                          subjectMatterSubjectTerms
# 34364     11805                     subjectMatterIconographicTerms
# 34365     11805                       subjectMatterConceptualTerms
#
#                                                  caption  number_of_tokens
# 0      Une scène religieuse présente une figure centr...                56
# 1      À l'image, il y a deux personnes sur une croix...                34
# 2      L'image présente une peinture avec un schéma d...                28
# 3                                     L'image est sombre                 8
# 4      En regardant cette image, je ressens un sentim...                23
# ...                                                  ...               ...
# 34361         figure femme en buste vêtement robe coiffe                15
# 34362                        figure homme en buste habit                 8
# 34363   groupe de figures ouvrier bâtiment voûte machine                17
# 34364                                      scène travail                 7
# 34365                            industrie métallurgique                 9
#
# [33792 rows x 4 columns]

# %%
analyze_captions(clean_full_training_dataset)
# Out:
# C:\Users\victo\AppData\Local\Temp\ipykernel_1100\3513188944.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_dataset["number_of_tokens"] = training_dataset["caption"].apply(lambda x: len(tokenizer.encode(x)))
#                                              row_type  <= TOKEN_LIMIT tokens  \
# 10            subjectMatterIconographicInterpretation                     21
# 8              subjectMatterGeneralSubjectDescription                     92
# 9          subjectMatterSpecificSubjectIdentification                    106
# 0                           synthetic_caption:caption                   5271
# 5                           subjectMatterSubjectTerms                   3581
# 6                      subjectMatterIconographicTerms                   2809
# 1         synthetic_caption:What objects do you see ?                   5299
# 4   synthetic_caption:What emotion do you feel whe...                   5299
# 2          synthetic_caption:What colors do you see ?                   5299
# 3    synthetic_caption:Is this image bright or dark ?                   5301
# 7                        subjectMatterConceptualTerms                    670
#
#     > TOKEN_LIMIT tokens  % <= TOKEN_LIMIT tokens  % > TOKEN_LIMIT tokens  \
# 10                     5                    80.77                   19.23
# 8                      3                    96.84                    3.16
# 9                      2                    98.15                    1.85
# 0                     20                    99.62                    0.38
# 5                     10                    99.72                    0.28
# 6                      2                    99.93                    0.07
# 1                      1                    99.98                    0.02
# 4                      1                    99.98                    0.02
# 2                      0                   100.00                    0.00
# 3                      0                   100.00                    0.00
# 7                      0                   100.00                    0.00
#
#     Average overflow
# 10              2.40
# 8               3.67
# 9               9.50
# 0               6.10
# 5               3.40
# 6               3.00
# 1               3.00
# 4               5.00
# 2                NaN
# 3                NaN
# 7                NaN

# %%
clean_full_training_dataset.to_csv(PARENT + os.getenv("FILE_FULL_TRAINING_DATASET"), index=False)
print("Exported !")
# Out:
# Exported !
