# %%
from database import MockDB
import pandas as pd
from dotenv import load_dotenv
import os
import random
import torch
import json
import matplotlib.pyplot as plt
import numpy as np

# %%
# loading variables from .env file
load_dotenv("../../../private_data/.env") 

# PARENT gets us to the root of the project
PARENT = "./../../../"

FOLDER_TABLE = PARENT + os.getenv("FOLDER_TABLE")
FILE_FABRITIUS_DATA = PARENT + os.getenv("FILE_FABRITIUS_DATA")
FILE_FABRITIUS_DATA_FILTERED = PARENT + os.getenv("FILE_FABRITIUS_DATA_FILTERED")
FILE_FABRITIUS_DATA_FILTERED_DOWNLOADED = PARENT + os.getenv("FILE_FABRITIUS_DATA_FILTERED_DOWNLOADED")
FOLDER_FIGURES = PARENT + os.getenv("FOLDER_FIGURES")
IMAGES_FOLDER = PARENT + os.getenv("IMAGES_FOLDER")
RECORD_IDS_TESTING_SET = PARENT + os.getenv("RECORD_IDS_TESTING_SET")
RECORD_IDS_VALIDATION_SET = PARENT + os.getenv("RECORD_IDS_VALIDATION_SET")
WRITTEN_CAPTIONS_TESTING_SET = PARENT + os.getenv("WRITTEN_CAPTIONS_TESTING_SET")
WRITTEN_CAPTIONS_VALIDATION_SET = PARENT + os.getenv("WRITTEN_CAPTIONS_VALIDATION_SET")
FILE_FABRITIUS_ICONOGRAPHIES_JSON = PARENT + os.getenv("FILE_FABRITIUS_ICONOGRAPHIES_JSON")
EMBEDDINGS_FOLDER = PARENT + os.getenv("EMBEDDINGS_FOLDER")
MODELS_FOLDER = PARENT + os.getenv("MODELS_FOLDER")

##

safeFormat = lambda x : x.replace("/", "_").replace(":", "_").replace(" ", "_")
model_name = "ViT-L/14"
embedding_name = safeFormat(model_name) + "_embeddings.npy"
path_imagesEmbeddings = os.path.join(EMBEDDINGS_FOLDER, "images_" + embedding_name)
path_objectsEmbeddings = os.path.join(EMBEDDINGS_FOLDER, "objects_" + embedding_name)
path_othersEmbeddings = os.path.join(EMBEDDINGS_FOLDER, "others_" + embedding_name)

# %%
FULL_DATASET = pd.read_csv(FILE_FABRITIUS_DATA_FILTERED_DOWNLOADED)
# Remove rows with corrupted images
FULL_DATASET = FULL_DATASET[FULL_DATASET["recordID"] != 11546]
FULL_DATASET = FULL_DATASET[FULL_DATASET["recordID"] != 5262]

# %%
with open(FILE_FABRITIUS_ICONOGRAPHIES_JSON, "r", encoding="utf-8") as f:
    ICONOGRAPHIES = json.load(f)

# %%
ICONOGRAPHIES
# Out:
# {'10002': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'homme', 'children': [], 'depth': 2},
#      {'value': 'barbe', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10004': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'homme',
#       'children': [{'value': 'chapeau', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'femme',
#       'children': [{'value': 'assis', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'pinceau', 'children': [], 'depth': 2}],
#     'depth': 1},
#    {'value': 'intérieur',
#     'children': [{'value': 'atelier', 'children': [], 'depth': 2},
#      {'value': 'chevalet', 'children': [], 'depth': 2},
#      {'value': 'tableau', 'children': [], 'depth': 2},
#      {'value': 'toile', 'children': [], 'depth': 2},
#      {'value': 'table', 'children': [], 'depth': 2},
#      {'value': 'livre', 'children': [], 'depth': 2},
#      {'value': 'fleur', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10005': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'femme',
#       'children': [{'value': 'en buste', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'de profil', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10016': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'homme', 'children': [], 'depth': 2},
#      {'value': 'femme', 'children': [], 'depth': 2},
#      {'value': 'foule', 'children': [], 'depth': 2},
#      {'value': 'soldat', 'children': [], 'depth': 2},
#      {'value': 'casque', 'children': [], 'depth': 2},
#      {'value': 'arme',
#       'children': [{'value': 'lance', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'animal',
#       'children': [{'value': 'cheval', 'children': [], 'depth': 3},
#        {'value': 'chien', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'coiffure', 'children': [], 'depth': 2},
#      {'value': 'couronne',
#       'children': [{'value': 'épine', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'nu', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '1003': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'femme',
#       'children': [{'value': 'en pied', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'de profil', 'children': [], 'depth': 2},
#      {'value': 'vêtement',
#       'children': [{'value': 'robe', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'noeud', 'children': [], 'depth': 2},
#      {'value': 'chapeau', 'children': [], 'depth': 2},
#      {'value': 'animal',
#       'children': [{'value': 'chien', 'children': [], 'depth': 3}],
#       'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10094': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'femme',
#       'children': [{'value': 'à mi-corps', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'couvre-chef', 'children': [], 'depth': 2},
#      {'value': 'parure', 'children': [], 'depth': 2},
#      {'value': 'vêtement', 'children': [], 'depth': 2},
#      {'value': 'harnachement', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '1010': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'homme', 'children': [], 'depth': 2},
#      {'value': 'habit',
#       'children': [{'value': 'veste', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'livre', 'children': [], 'depth': 2},
#      {'value': 'pinceau', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10116': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'jeune fille', 'children': [], 'depth': 2},
#      {'value': 'enfant',
#       'children': [{'value': 'fillette', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'coiffe', 'children': [], 'depth': 2},
#      {'value': 'vêtement', 'children': [], 'depth': 2},
#      {'value': 'chapelet', 'children': [], 'depth': 2},
#      {'value': 'gonfanon', 'children': [], 'depth': 2}],
#     'depth': 1},
#    {'value': '<group>',
#     'children': [{'value': 'intérieur',
#       'children': [{'value': 'église', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'chandelle', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10136': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'femme',
#       'children': [{'value': 'en buste', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'de profil', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10137': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'femme',
#       'children': [{'value': 'de profil', 'children': [], 'depth': 3}],
#       'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10138': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'homme',
#       'children': [{'value': 'en pied', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'vêtement',
#       'children': [{'value': 'chapeau', 'children': [], 'depth': 3}],
#       'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10139': {'value': 'root',
#   'children': [{'value': 'paysage',
#     'children': [{'value': 'village', 'children': [], 'depth': 2},
#      {'value': 'maison', 'children': [], 'depth': 2},
#      {'value': 'arbre', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10140': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'homme',
#       'children': [{'value': 'à mi-corps', 'children': [], 'depth': 3}],
#       'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10153': {'value': 'root',
#   'children': [{'value': 'représentation animalière',
#     'children': [{'value': 'animal',
#       'children': [{'value': 'chien', 'children': [], 'depth': 3}],
#       'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10154': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'femme',
#       'children': [{'value': 'assis', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'vêtement',
#       'children': [{'value': 'robe', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'tissu', 'children': [], 'depth': 2},
#      {'value': 'bijou', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10155': {'value': 'root',
#   'children': [{'value': '<group>',
#     'children': [{'value': 'port', 'children': [], 'depth': 2},
#      {'value': 'quai', 'children': [], 'depth': 2},
#      {'value': 'bateau',
#       'children': [{'value': 'bateau à voiles', 'children': [], 'depth': 3}],
#       'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10156': {'value': 'root',
#   'children': [{'value': 'paysage',
#     'children': [{'value': 'pont', 'children': [], 'depth': 2},
#      {'value': 'rocher', 'children': [], 'depth': 2},
#      {'value': 'arbre', 'children': [], 'depth': 2},
#      {'value': 'rive', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10163': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'femme', 'children': [], 'depth': 2},
#      {'value': 'enfant',
#       'children': [{'value': 'nourrisson', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'homme', 'children': [], 'depth': 2},
#      {'value': 'religieux',
#       'children': [{'value': 'prêtre', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'vêtement',
#       'children': [{'value': 'fourrure', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'couvre-chef',
#       'children': [{'value': 'coiffe', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'chapeau', 'children': [], 'depth': 2},
#      {'value': 'couronne', 'children': [], 'depth': 2},
#      {'value': 'coiffure', 'children': [], 'depth': 2},
#      {'value': 'bijou', 'children': [], 'depth': 2},
#      {'value': 'chaussure', 'children': [], 'depth': 2}],
#     'depth': 1},
#    {'value': 'intérieur',
#     'children': [{'value': 'lit',
#       'children': [{'value': 'baldaquin', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'table', 'children': [], 'depth': 2},
#      {'value': 'cruche', 'children': [], 'depth': 2},
#      {'value': 'plat', 'children': [], 'depth': 2},
#      {'value': 'cuillère', 'children': [], 'depth': 2}],
#     'depth': 1},
#    {'value': 'architecture',
#     'children': [{'value': 'pilastre', 'children': [], 'depth': 2},
#      {'value': 'fenêtre', 'children': [], 'depth': 2},
#      {'value': 'pavement', 'children': [], 'depth': 2},
#      {'value': 'bâtiment', 'children': [], 'depth': 2},
#      {'value': 'escalier', 'children': [], 'depth': 2},
#      {'value': 'colonne', 'children': [], 'depth': 2},
#      {'value': 'sculpture',
#       'children': [{'value': 'statue', 'children': [], 'depth': 3}],
#       'depth': 2}],
#     'depth': 1},
#    {'value': 'fond de paysage',
#     'children': [{'value': 'arbre', 'children': [], 'depth': 2},
#      {'value': 'ville', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10165': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'homme',
#       'children': [{'value': 'vieux', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'barbe', 'children': [], 'depth': 2},
#      {'value': 'religieux',
#       'children': [{'value': 'prêtre', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'vêtement', 'children': [], 'depth': 2},
#      {'value': 'couvre-chef', 'children': [], 'depth': 2},
#      {'value': 'monnaie', 'children': [], 'depth': 2},
#      {'value': 'autel', 'children': [], 'depth': 2},
#      {'value': 'livre', 'children': [], 'depth': 2}],
#     'depth': 1},
#    {'value': '<group>',
#     'children': [{'value': 'femme',
#       'children': [{'value': 'agenouillé', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'coiffure', 'children': [], 'depth': 2},
#      {'value': 'froc', 'children': [], 'depth': 2},
#      {'value': 'enfant',
#       'children': [{'value': 'nu', 'children': [], 'depth': 3}],
#       'depth': 2}],
#     'depth': 1},
#    {'value': 'architecture',
#     'children': [{'value': 'pilier', 'children': [], 'depth': 2},
#      {'value': 'pavement', 'children': [], 'depth': 2},
#      {'value': 'colonne', 'children': [], 'depth': 2},
#      {'value': 'baldaquin', 'children': [], 'depth': 2}],
#     'depth': 1},
#    {'value': 'paysage de fond',
#     'children': [{'value': 'colline', 'children': [], 'depth': 2},
#      {'value': 'animal',
#       'children': [{'value': 'mouton', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'être imaginaire',
#       'children': [{'value': 'aile', 'children': [], 'depth': 3}],
#       'depth': 2}],
#     'depth': 1},
#    {'value': '<group>',
#     'children': [{'value': 'bâtiment', 'children': [], 'depth': 2},
#      {'value': 'rocher', 'children': [], 'depth': 2},
#      {'value': 'arbre', 'children': [], 'depth': 2},
#      {'value': 'branche', 'children': [], 'depth': 2},
#      {'value': 'fleur', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10166': {'value': 'root',
#   'children': [{'value': 'architecture',
#     'children': [{'value': 'église',
#       'children': [{'value': 'intérieur', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'voûte', 'children': [], 'depth': 2},
#      {'value': 'colonne', 'children': [], 'depth': 2},
#      {'value': 'vitrail', 'children': [], 'depth': 2},
#      {'value': 'chapelle', 'children': [], 'depth': 2},
#      {'value': 'jubé', 'children': [], 'depth': 2},
#      {'value': 'pavement', 'children': [], 'depth': 2},
#      {'value': 'mobilier religieux',
#       'children': [{'value': 'autel', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'chaire à prêcher', 'children': [], 'depth': 2},
#      {'value': 'retable', 'children': [], 'depth': 2},
#      {'value': 'instrument de musique',
#       'children': [{'value': 'orgue', 'children': [], 'depth': 3}],
#       'depth': 2}],
#     'depth': 1},
#    {'value': 'groupe de figures',
#     'children': [{'value': 'homme',
#       'children': [{'value': 'prêtre', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'femme', 'children': [], 'depth': 2},
#      {'value': 'enfant', 'children': [], 'depth': 2},
#      {'value': 'fidèles', 'children': [], 'depth': 2},
#      {'value': 'vêtement', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10167': {'value': 'root', 'children': [], 'depth': 0},
#  '10168': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'homme',
#       'children': [{'value': 'assis', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'en appui', 'children': [], 'depth': 2},
#      {'value': 'vêtement', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10169': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'homme',
#       'children': [{'value': 'assis', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'vêtement',
#       'children': [{'value': 'voile', 'children': [], 'depth': 3}],
#       'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10172': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'femme',
#       'children': [{'value': 'nu', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'fleur', 'children': [], 'depth': 2},
#      {'value': 'coiffure', 'children': [], 'depth': 2},
#      {'value': 'bijou', 'children': [], 'depth': 2},
#      {'value': 'homme',
#       'children': [{'value': 'agenouillé', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'crâne', 'children': [], 'depth': 2},
#      {'value': 'livre', 'children': [], 'depth': 2},
#      {'value': 'animal',
#       'children': [{'value': 'hibou', 'children': [], 'depth': 3}],
#       'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10173': {'value': 'root',
#   'children': [{'value': 'marine',
#     'children': [{'value': 'bateau',
#       'children': [{'value': 'bateau à voiles', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'petit voilier', 'children': [], 'depth': 2},
#      {'value': 'mer', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10201': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'homme',
#       'children': [{'value': 'assis', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'de profil', 'children': [], 'depth': 2},
#      {'value': 'bâton', 'children': [], 'depth': 2},
#      {'value': 'arbre', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10203': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'homme',
#       'children': [{'value': 'foule', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'arme', 'children': [], 'depth': 2},
#      {'value': 'animal',
#       'children': [{'value': 'cheval', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'croix', 'children': [], 'depth': 2},
#      {'value': 'drapeau', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10204': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'homme', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10207': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'homme',
#       'children': [{'value': 'à mi-corps', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'de profil', 'children': [], 'depth': 2},
#      {'value': 'couvre-chef', 'children': [], 'depth': 2},
#      {'value': 'outil',
#       'children': [{'value': 'houe', 'children': [], 'depth': 3}],
#       'depth': 2}],
#     'depth': 1},
#    {'value': '<group>',
#     'children': [{'value': 'cheminée', 'children': [], 'depth': 2},
#      {'value': 'fumée', 'children': [], 'depth': 2},
#      {'value': 'bâtiment',
#       'children': [{'value': 'toit', 'children': [], 'depth': 3}],
#       'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10209': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'homme', 'children': [], 'depth': 2},
#      {'value': 'femme', 'children': [], 'depth': 2},
#      {'value': 'enfant', 'children': [], 'depth': 2},
#      {'value': 'échelle', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10210': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'homme',
#       'children': [{'value': 'cadavre', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'branche', 'children': [], 'depth': 2},
#      {'value': 'fumier', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10212': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'homme',
#       'children': [{'value': 'en pied', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'arme',
#       'children': [{'value': 'épée', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'bouclier', 'children': [], 'depth': 2},
#      {'value': 'casque', 'children': [], 'depth': 2},
#      {'value': 'cuirasse', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10213': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'homme', 'children': [], 'depth': 2}],
#     'depth': 1},
#    {'value': 'architecture',
#     'children': [{'value': 'usine', 'children': [], 'depth': 2},
#      {'value': 'fourneau', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10214': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'ouvrier', 'children': [], 'depth': 2},
#      {'value': 'outil',
#       'children': [{'value': 'pince', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'machine', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10215': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'homme', 'children': [], 'depth': 2},
#      {'value': 'roue', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10216': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'homme',
#       'children': [{'value': 'assis', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'couvre-chef', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10217': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'homme',
#       'children': [{'value': 'cadavre', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'branche', 'children': [], 'depth': 2},
#      {'value': 'fumier', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10218': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'homme',
#       'children': [{'value': 'agenouillé', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'main',
#       'children': [{'value': 'joint', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'chandelle', 'children': [], 'depth': 2},
#      {'value': 'autel', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10219': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'femme',
#       'children': [{'value': 'en pied', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'homme', 'children': [], 'depth': 2},
#      {'value': 'combat', 'children': [], 'depth': 2},
#      {'value': 'flamme', 'children': [], 'depth': 2}],
#     'depth': 1},
#    {'value': 'intérieur',
#     'children': [{'value': 'tabouret', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10220': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'homme',
#       'children': [{'value': 'cadavre', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'lit', 'children': [], 'depth': 2},
#      {'value': 'femme', 'children': [], 'depth': 2},
#      {'value': 'chaussure', 'children': [], 'depth': 2}],
#     'depth': 1},
#    {'value': 'intérieur',
#     'children': [{'value': 'crucifix', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10221': {'value': 'root', 'children': [], 'depth': 0},
#  '10223': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'foule', 'children': [], 'depth': 2},
#      {'value': 'homme', 'children': [], 'depth': 2},
#      {'value': 'femme', 'children': [], 'depth': 2},
#      {'value': 'enfant', 'children': [], 'depth': 2},
#      {'value': 'vêtement',
#       'children': [{'value': 'local', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'couvre-chef', 'children': [], 'depth': 2},
#      {'value': 'coiffure', 'children': [], 'depth': 2},
#      {'value': 'coiffe', 'children': [], 'depth': 2},
#      {'value': 'fleur', 'children': [], 'depth': 2},
#      {'value': 'panier', 'children': [], 'depth': 2},
#      {'value': 'croix', 'children': [], 'depth': 2}],
#     'depth': 1},
#    {'value': 'architecture',
#     'children': [{'value': 'église', 'children': [], 'depth': 2},
#      {'value': 'façade', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10225': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'homme',
#       'children': [{'value': 'religieux', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'femme', 'children': [], 'depth': 2},
#      {'value': 'vêtement',
#       'children': [{'value': 'costume religieux', 'children': [], 'depth': 3}],
#       'depth': 2}],
#     'depth': 1},
#    {'value': 'paysage',
#     'children': [{'value': 'dune', 'children': [], 'depth': 2},
#      {'value': 'mer', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10229': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'homme',
#       'children': [{'value': 'soldat', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'assis', 'children': [], 'depth': 2},
#      {'value': 'femme', 'children': [], 'depth': 2},
#      {'value': 'enfant',
#       'children': [{'value': 'nourrisson', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'animal',
#       'children': [{'value': 'cheval', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'chien', 'children': [], 'depth': 2},
#      {'value': 'uniforme', 'children': [], 'depth': 2},
#      {'value': 'armure',
#       'children': [{'value': 'casque', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'plume', 'children': [], 'depth': 2},
#      {'value': 'chaumière', 'children': [], 'depth': 2},
#      {'value': 'seau', 'children': [], 'depth': 2},
#      {'value': 'panier', 'children': [], 'depth': 2},
#      {'value': 'hache', 'children': [], 'depth': 2},
#      {'value': 'échelle', 'children': [], 'depth': 2},
#      {'value': 'pot', 'children': [], 'depth': 2},
#      {'value': 'palissade', 'children': [], 'depth': 2},
#      {'value': 'mare', 'children': [], 'depth': 2},
#      {'value': 'arbre', 'children': [], 'depth': 2},
#      {'value': 'plante', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '1023': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'homme', 'children': [], 'depth': 2},
#      {'value': 'femme', 'children': [], 'depth': 2},
#      {'value': 'enfant',
#       'children': [{'value': 'nourrisson', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'vêtement',
#       'children': [{'value': 'habit', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'col',
#       'children': [{'value': 'dentelle', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'couvre-chef',
#       'children': [{'value': 'coiffe', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'aliment',
#       'children': [{'value': 'fruit', 'children': [], 'depth': 3},
#        {'value': 'raisin', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'moustache', 'children': [], 'depth': 2},
#      {'value': 'toile', 'children': [], 'depth': 2},
#      {'value': 'statue', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10240': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'homme', 'children': [], 'depth': 2},
#      {'value': 'femme', 'children': [], 'depth': 2},
#      {'value': 'enfant',
#       'children': [{'value': 'en pied', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'couvre-chef',
#       'children': [{'value': 'chapeau', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'coiffe', 'children': [], 'depth': 2},
#      {'value': 'bâton', 'children': [], 'depth': 2},
#      {'value': 'bateau',
#       'children': [{'value': 'bateau à rames', 'children': [], 'depth': 3}],
#       'depth': 2}],
#     'depth': 1},
#    {'value': 'fond de paysage',
#     'children': [{'value': 'eau', 'children': [], 'depth': 2},
#      {'value': 'arbre', 'children': [], 'depth': 2},
#      {'value': 'buisson', 'children': [], 'depth': 2},
#      {'value': 'plante aquatique',
#       'children': [{'value': 'roseau', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'bâtiment',
#       'children': [{'value': 'maison', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'moulin à eau', 'children': [], 'depth': 2},
#      {'value': 'lune', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10241': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'homme', 'children': [], 'depth': 2},
#      {'value': 'femme',
#       'children': [{'value': 'en pied', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'couvre-chef',
#       'children': [{'value': 'casque', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'coiffure', 'children': [], 'depth': 2},
#      {'value': 'arme',
#       'children': [{'value': 'lance', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'arc', 'children': [], 'depth': 2},
#      {'value': 'barbe', 'children': [], 'depth': 2},
#      {'value': 'animal',
#       'children': [{'value': 'chien', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'arbre', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10249': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'femme',
#       'children': [{'value': 'assis', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'de profil', 'children': [], 'depth': 2},
#      {'value': 'couvre-chef',
#       'children': [{'value': 'coiffe', 'children': [], 'depth': 3}],
#       'depth': 2}],
#     'depth': 1},
#    {'value': 'fond de paysage',
#     'children': [{'value': 'champ', 'children': [], 'depth': 2},
#      {'value': 'colline', 'children': [], 'depth': 2},
#      {'value': 'arbre', 'children': [], 'depth': 2},
#      {'value': 'buisson', 'children': [], 'depth': 2},
#      {'value': 'animal',
#       'children': [{'value': 'vache', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'chèvre', 'children': [], 'depth': 2},
#      {'value': 'mouton', 'children': [], 'depth': 2},
#      {'value': 'oiseau', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10250': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'homme', 'children': [], 'depth': 2},
#      {'value': 'port', 'children': [], 'depth': 2},
#      {'value': 'bateau', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10252': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'agenouillé', 'children': [], 'depth': 2},
#      {'value': 'cape', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10253': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'homme',
#       'children': [{'value': 'en pied', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'de dos', 'children': [], 'depth': 2},
#      {'value': 'religieux', 'children': [], 'depth': 2},
#      {'value': 'costume religieux',
#       'children': [{'value': 'froc', 'children': [], 'depth': 3}],
#       'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10254': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'femme',
#       'children': [{'value': 'penché', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'homme',
#       'children': [{'value': 'mort', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'cercueil', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10258': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'homme',
#       'children': [{'value': 'en pied', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'couvre-chef',
#       'children': [{'value': 'chapeau', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'animal',
#       'children': [{'value': 'âne', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'mouton', 'children': [], 'depth': 2},
#      {'value': 'chien', 'children': [], 'depth': 2}],
#     'depth': 1},
#    {'value': 'fond de paysage',
#     'children': [{'value': 'forêt', 'children': [], 'depth': 2},
#      {'value': 'eau', 'children': [], 'depth': 2},
#      {'value': 'cascade', 'children': [], 'depth': 2},
#      {'value': 'pont', 'children': [], 'depth': 2},
#      {'value': 'animal',
#       'children': [{'value': 'oiseau', 'children': [], 'depth': 3}],
#       'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10263': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'homme', 'children': [], 'depth': 2},
#      {'value': 'femme',
#       'children': [{'value': 'couché', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'agenouillé', 'children': [], 'depth': 2},
#      {'value': 'couvre-chef',
#       'children': [{'value': 'coiffe', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'auréole', 'children': [], 'depth': 2},
#      {'value': 'couronne',
#       'children': [{'value': 'épine', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'barbe', 'children': [], 'depth': 2},
#      {'value': 'clou', 'children': [], 'depth': 2},
#      {'value': 'cruche', 'children': [], 'depth': 2},
#      {'value': 'feuillet', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10265': {'value': 'root',
#   'children': [{'value': 'scène',
#     'children': [{'value': 'homme', 'children': [], 'depth': 2},
#      {'value': 'femme', 'children': [], 'depth': 2},
#      {'value': 'enfant', 'children': [], 'depth': 2},
#      {'value': 'vêtement',
#       'children': [{'value': 'robe', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'couvre-chef',
#       'children': [{'value': 'coiffe', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'chaîne', 'children': [], 'depth': 2},
#      {'value': 'barbe', 'children': [], 'depth': 2},
#      {'value': 'toile', 'children': [], 'depth': 2},
#      {'value': 'mort', 'children': [], 'depth': 2}],
#     'depth': 1},
#    {'value': 'fond de paysage',
#     'children': [{'value': 'montagne', 'children': [], 'depth': 2},
#      {'value': 'arbre', 'children': [], 'depth': 2},
#      {'value': 'rocher', 'children': [], 'depth': 2},
#      {'value': 'croix', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '1029': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'femme',
#       'children': [{'value': 'assis', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'vêtement',
#       'children': [{'value': 'robe', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'gant', 'children': [], 'depth': 2},
#      {'value': 'chaussure', 'children': [], 'depth': 2},
#      {'value': 'bijou',
#       'children': [{'value': 'anneau', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'noeud', 'children': [], 'depth': 2},
#      {'value': 'éventail', 'children': [], 'depth': 2}],
#     'depth': 1},
#    {'value': 'intérieur',
#     'children': [{'value': 'meuble',
#       'children': [{'value': 'canapé', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'tapis', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10294': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'femme', 'children': [], 'depth': 2},
#      {'value': 'homme', 'children': [], 'depth': 2},
#      {'value': 'enfant', 'children': [], 'depth': 2},
#      {'value': 'animal',
#       'children': [{'value': 'chien', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'couvre-chef', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10297': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'femme', 'children': [], 'depth': 2},
#      {'value': 'homme', 'children': [], 'depth': 2},
#      {'value': 'enfant', 'children': [], 'depth': 2},
#      {'value': 'couvre-chef', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10310': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'homme', 'children': [], 'depth': 2},
#      {'value': 'barbe', 'children': [], 'depth': 2},
#      {'value': 'vêtement',
#       'children': [{'value': 'draperie', 'children': [], 'depth': 3}],
#       'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10311': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'femme', 'children': [], 'depth': 2},
#      {'value': 'homme',
#       'children': [{'value': 'barbe', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'enfant', 'children': [], 'depth': 2},
#      {'value': 'animal',
#       'children': [{'value': 'agneau', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'coiffe', 'children': [], 'depth': 2},
#      {'value': 'croix', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10328': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'homme',
#       'children': [{'value': 'de profil', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'en buste', 'children': [], 'depth': 2},
#      {'value': 'barbe', 'children': [], 'depth': 2},
#      {'value': 'moustache', 'children': [], 'depth': 2},
#      {'value': 'couvre-chef',
#       'children': [{'value': 'local', 'children': [], 'depth': 3}],
#       'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10329': {'value': 'root',
#   'children': [{'value': 'architecture',
#     'children': [{'value': 'kiosque', 'children': [], 'depth': 2},
#      {'value': 'colonne', 'children': [], 'depth': 2},
#      {'value': 'chapiteau', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '1033': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'homme', 'children': [], 'depth': 2},
#      {'value': 'femme', 'children': [], 'depth': 2},
#      {'value': 'enfant',
#       'children': [{'value': 'fillette', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'en pied', 'children': [], 'depth': 2},
#      {'value': 'assis', 'children': [], 'depth': 2},
#      {'value': 'animal',
#       'children': [{'value': 'chien', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'vêtement',
#       'children': [{'value': 'habit', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'robe', 'children': [], 'depth': 2},
#      {'value': 'tablier', 'children': [], 'depth': 2},
#      {'value': 'couvre-chef',
#       'children': [{'value': 'coiffe', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'chapeau', 'children': [], 'depth': 2},
#      {'value': 'lunettes', 'children': [], 'depth': 2},
#      {'value': 'moustache', 'children': [], 'depth': 2},
#      {'value': 'bâton', 'children': [], 'depth': 2},
#      {'value': 'coffre', 'children': [], 'depth': 2}],
#     'depth': 1},
#    {'value': 'intérieur',
#     'children': [{'value': 'meuble',
#       'children': [{'value': 'armoire', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'chaise', 'children': [], 'depth': 2},
#      {'value': 'table', 'children': [], 'depth': 2},
#      {'value': 'escalier', 'children': [], 'depth': 2},
#      {'value': 'fenêtre', 'children': [], 'depth': 2},
#      {'value': 'rideau', 'children': [], 'depth': 2},
#      {'value': 'pavement', 'children': [], 'depth': 2},
#      {'value': 'statue', 'children': [], 'depth': 2},
#      {'value': 'affiche', 'children': [], 'depth': 2},
#      {'value': 'tableau', 'children': [], 'depth': 2},
#      {'value': 'plante', 'children': [], 'depth': 2},
#      {'value': 'fleur', 'children': [], 'depth': 2},
#      {'value': 'assiette', 'children': [], 'depth': 2},
#      {'value': 'bouteille', 'children': [], 'depth': 2},
#      {'value': 'gobelet', 'children': [], 'depth': 2},
#      {'value': 'boîte', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10330': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'femme',
#       'children': [{'value': 'en appui', 'children': [], 'depth': 3}],
#       'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10331': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'homme', 'children': [], 'depth': 2},
#      {'value': 'vêtement',
#       'children': [{'value': 'local', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'couvre-chef', 'children': [], 'depth': 2},
#      {'value': 'animal',
#       'children': [{'value': 'dromadaire', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'caravane', 'children': [], 'depth': 2},
#      {'value': 'désert', 'children': [], 'depth': 2},
#      {'value': 'arbre',
#       'children': [{'value': 'palmier', 'children': [], 'depth': 3}],
#       'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10332': {'value': 'root',
#   'children': [{'value': 'paysage',
#     'children': [{'value': 'désert', 'children': [], 'depth': 2},
#      {'value': 'arbre', 'children': [], 'depth': 2},
#      {'value': 'montagne', 'children': [], 'depth': 2},
#      {'value': 'architecture', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10333': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'femme',
#       'children': [{'value': 'assis', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'de profil', 'children': [], 'depth': 2},
#      {'value': 'couvre-chef',
#       'children': [{'value': 'coiffe', 'children': [], 'depth': 3},
#        {'value': 'local', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'panier', 'children': [], 'depth': 2},
#      {'value': 'bijou', 'children': [], 'depth': 2},
#      {'value': 'aliment', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10334': {'value': 'root',
#   'children': [{'value': 'architecture',
#     'children': [{'value': 'rempart', 'children': [], 'depth': 2},
#      {'value': 'ville', 'children': [], 'depth': 2},
#      {'value': 'escalier', 'children': [], 'depth': 2},
#      {'value': 'maison', 'children': [], 'depth': 2},
#      {'value': 'colonne', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10335': {'value': 'root',
#   'children': [{'value': 'architecture',
#     'children': [{'value': 'ville', 'children': [], 'depth': 2},
#      {'value': 'mosquée', 'children': [], 'depth': 2},
#      {'value': 'coupole', 'children': [], 'depth': 2},
#      {'value': 'arbre', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10336': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'homme',
#       'children': [{'value': 'de profil', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'barbe', 'children': [], 'depth': 2},
#      {'value': 'femme',
#       'children': [{'value': 'à mi-corps', 'children': [], 'depth': 3}],
#       'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10337': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'femme',
#       'children': [{'value': 'en pied', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'vêtement',
#       'children': [{'value': 'draperie', 'children': [], 'depth': 3}],
#       'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10338': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'homme', 'children': [], 'depth': 2},
#      {'value': 'femme', 'children': [], 'depth': 2},
#      {'value': 'être imaginaire',
#       'children': [{'value': 'aile', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'lune', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10339': {'value': 'root',
#   'children': [{'value': 'paysage',
#     'children': [{'value': 'maison', 'children': [], 'depth': 2},
#      {'value': 'mosquée', 'children': [], 'depth': 2},
#      {'value': 'minaret', 'children': [], 'depth': 2},
#      {'value': 'arbre', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10340': {'value': 'root',
#   'children': [{'value': 'architecture',
#     'children': [{'value': 'maison', 'children': [], 'depth': 2},
#      {'value': 'coupole', 'children': [], 'depth': 2},
#      {'value': 'minaret', 'children': [], 'depth': 2},
#      {'value': 'arbre',
#       'children': [{'value': 'palmier', 'children': [], 'depth': 3}],
#       'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10341': {'value': 'root', 'children': [], 'depth': 0},
#  '10343': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'homme',
#       'children': [{'value': 'en buste', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'barbe', 'children': [], 'depth': 2},
#      {'value': 'moustache', 'children': [], 'depth': 2},
#      {'value': 'couvre-chef',
#       'children': [{'value': 'local', 'children': [], 'depth': 3}],
#       'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10344': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'femme',
#       'children': [{'value': 'nu', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'couché', 'children': [], 'depth': 2},
#      {'value': 'lit', 'children': [], 'depth': 2},
#      {'value': 'coussin', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10345': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'homme',
#       'children': [{'value': 'assis', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'vêtement',
#       'children': [{'value': 'local', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'couvre-chef', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10346': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'homme', 'children': [], 'depth': 2},
#      {'value': 'enfant',
#       'children': [{'value': 'assis', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'couvre-chef',
#       'children': [{'value': 'local', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'livre', 'children': [], 'depth': 2},
#      {'value': 'architecture', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10347': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'homme',
#       'children': [{'value': 'en pied', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'profil', 'children': [], 'depth': 2},
#      {'value': 'serviteur', 'children': [], 'depth': 2},
#      {'value': 'vêtement',
#       'children': [{'value': 'couvre-chef', 'children': [], 'depth': 3}],
#       'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10348': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'femme', 'children': [], 'depth': 2},
#      {'value': 'enfant', 'children': [], 'depth': 2},
#      {'value': 'vêtement',
#       'children': [{'value': 'local', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'panier', 'children': [], 'depth': 2},
#      {'value': 'de dos', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10349': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'femme',
#       'children': [{'value': 'à mi-corps', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'de trois-quarts', 'children': [], 'depth': 2},
#      {'value': 'couvre-chef',
#       'children': [{'value': 'local', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'bijou', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10350': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'homme',
#       'children': [{'value': 'assis', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'femme', 'children': [], 'depth': 2},
#      {'value': 'enfant', 'children': [], 'depth': 2},
#      {'value': 'vêtement',
#       'children': [{'value': 'local', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'couvre-chef', 'children': [], 'depth': 2},
#      {'value': 'échoppe', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10351': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'couché', 'children': [], 'depth': 2},
#      {'value': 'cheveux', 'children': [], 'depth': 2},
#      {'value': 'désert', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10352': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'femme',
#       'children': [{'value': 'assis', 'children': [], 'depth': 3}],
#       'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10353': {'value': 'root',
#   'children': [{'value': 'marine',
#     'children': [{'value': 'bateau',
#       'children': [{'value': 'péniche', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'quai', 'children': [], 'depth': 2},
#      {'value': 'drapeau', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10356': {'value': 'root',
#   'children': [{'value': 'paysage',
#     'children': [{'value': 'arbre', 'children': [], 'depth': 2}],
#     'depth': 1},
#    {'value': 'figure',
#     'children': [{'value': 'femme',
#       'children': [{'value': 'assis', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'nu', 'children': [], 'depth': 2},
#      {'value': 'penché', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10357': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'homme', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10359': {'value': 'root',
#   'children': [{'value': 'marine',
#     'children': [{'value': 'bateau',
#       'children': [{'value': 'bateau à voiles', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'péniche', 'children': [], 'depth': 2},
#      {'value': 'quai', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '1036': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'femme', 'children': [], 'depth': 2},
#      {'value': 'enfant', 'children': [], 'depth': 2},
#      {'value': 'étreinte', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10360': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'homme',
#       'children': [{'value': 'assis', 'children': [], 'depth': 3}],
#       'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10361': {'value': 'root',
#   'children': [{'value': 'paysage',
#     'children': [{'value': 'forêt', 'children': [], 'depth': 2},
#      {'value': 'arbre', 'children': [], 'depth': 2},
#      {'value': 'maison', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10365': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'homme',
#       'children': [{'value': 'à mi-corps', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'habit', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '10366': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'femme',
#       'children': [{'value': 'assis', 'children': [], 'depth': 3}],
#       'depth': 2},
# ...
#      {'value': 'volaille', 'children': [], 'depth': 2},
#      {'value': 'poisson', 'children': [], 'depth': 2},
#      {'value': 'huître', 'children': [], 'depth': 2},
#      {'value': 'fruit', 'children': [], 'depth': 2},
#      {'value': 'légume', 'children': [], 'depth': 2},
#      {'value': 'figure',
#       'children': [{'value': 'femme', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'servante', 'children': [], 'depth': 2},
#      {'value': 'table', 'children': [], 'depth': 2},
#      {'value': 'panier', 'children': [], 'depth': 2},
#      {'value': 'crochet', 'children': [], 'depth': 2},
#      {'value': 'plat', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '3662': {'value': 'root',
#   'children': [{'value': 'scène',
#     'children': [{'value': 'homme',
#       'children': [{'value': 'nu', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'blessure', 'children': [], 'depth': 2},
#      {'value': 'auréole', 'children': [], 'depth': 2},
#      {'value': 'couronne', 'children': [], 'depth': 2},
#      {'value': 'épine', 'children': [], 'depth': 2}],
#     'depth': 1},
#    {'value': 'arme',
#     'children': [{'value': 'lance', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '3663': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'homme',
#       'children': [{'value': 'agenouillé', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'nu', 'children': [], 'depth': 2},
#      {'value': 'blessé', 'children': [], 'depth': 2},
#      {'value': 'tête', 'children': [], 'depth': 2},
#      {'value': 'main', 'children': [], 'depth': 2},
#      {'value': 'toile',
#       'children': [{'value': 'portrait', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'bourse', 'children': [], 'depth': 2},
#      {'value': 'couvre-chef',
#       'children': [{'value': 'chapeau', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'tiare', 'children': [], 'depth': 2},
#      {'value': 'costume religieux',
#       'children': [{'value': 'chasuble', 'children': [], 'depth': 3}],
#       'depth': 2}],
#     'depth': 1},
#    {'value': '<group>',
#     'children': [{'value': 'autel', 'children': [], 'depth': 2},
#      {'value': 'livre', 'children': [], 'depth': 2},
#      {'value': 'calice', 'children': [], 'depth': 2},
#      {'value': 'clou', 'children': [], 'depth': 2},
#      {'value': 'éponge', 'children': [], 'depth': 2},
#      {'value': 'arme',
#       'children': [{'value': 'lance', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'fouet', 'children': [], 'depth': 2},
#      {'value': 'couronne',
#       'children': [{'value': 'épine', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'croix', 'children': [], 'depth': 2},
#      {'value': 'chandelle', 'children': [], 'depth': 2},
#      {'value': 'jeu de dés', 'children': [], 'depth': 2}],
#     'depth': 1},
#    {'value': 'architecture',
#     'children': [{'value': 'vitrail', 'children': [], 'depth': 2},
#      {'value': 'colonne', 'children': [], 'depth': 2},
#      {'value': 'chapiteau',
#       'children': [{'value': 'sculpture', 'children': [], 'depth': 3}],
#       'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '3664': {'value': 'root',
#   'children': [{'value': 'scène',
#     'children': [{'value': 'femme', 'children': [], 'depth': 2},
#      {'value': 'enfant',
#       'children': [{'value': 'nourrisson', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'mère', 'children': [], 'depth': 2},
#      {'value': 'aliment', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '3665': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'homme',
#       'children': [{'value': 'de trois-quarts', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'bonnet', 'children': [], 'depth': 2},
#      {'value': 'bijou', 'children': [], 'depth': 2},
#      {'value': 'armoiries', 'children': [], 'depth': 2},
#      {'value': 'or', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '3666': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'homme', 'children': [], 'depth': 2},
#      {'value': 'bijou', 'children': [], 'depth': 2},
#      {'value': 'gril', 'children': [], 'depth': 2},
#      {'value': 'livre', 'children': [], 'depth': 2},
#      {'value': 'phylactère', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '3667': {'value': 'root',
#   'children': [{'value': 'scène',
#     'children': [{'value': 'homme', 'children': [], 'depth': 2},
#      {'value': 'femme', 'children': [], 'depth': 2},
#      {'value': 'enfant',
#       'children': [{'value': 'nourrisson', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'croix', 'children': [], 'depth': 2},
#      {'value': 'crâne', 'children': [], 'depth': 2}],
#     'depth': 1},
#    {'value': 'animal',
#     'children': [{'value': 'boeuf', 'children': [], 'depth': 2}],
#     'depth': 1},
#    {'value': 'animal fabuleux',
#     'children': [{'value': 'dragon', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '3668': {'value': 'root',
#   'children': [{'value': 'scène',
#     'children': [{'value': 'femme',
#       'children': [{'value': 'agenouillé', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'vêtement',
#       'children': [{'value': 'robe', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'homme', 'children': [], 'depth': 2},
#      {'value': 'croix', 'children': [], 'depth': 2},
#      {'value': 'architecture',
#       'children': [{'value': 'ville', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'coupole', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '3669': {'value': 'root', 'children': [], 'depth': 0},
#  '367': {'value': 'root',
#   'children': [{'value': 'aliment',
#     'children': [{'value': 'champignon', 'children': [], 'depth': 2}],
#     'depth': 1},
#    {'value': 'fruit',
#     'children': [{'value': 'melon', 'children': [], 'depth': 2}],
#     'depth': 1},
#    {'value': 'légume',
#     'children': [{'value': 'céleri', 'children': [], 'depth': 2}],
#     'depth': 1},
#    {'value': 'animal',
#     'children': [{'value': 'oiseau', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '3670': {'value': 'root',
#   'children': [{'value': 'groupe',
#     'children': [{'value': 'femme', 'children': [], 'depth': 2},
#      {'value': 'enfant',
#       'children': [{'value': 'nourrisson', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'rayons lumineux', 'children': [], 'depth': 2},
#      {'value': 'broderie', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '3671': {'value': 'root',
#   'children': [{'value': 'paysage',
#     'children': [{'value': 'vallée', 'children': [], 'depth': 2},
#      {'value': 'rocher', 'children': [], 'depth': 2},
#      {'value': 'montagne', 'children': [], 'depth': 2},
#      {'value': 'charrette', 'children': [], 'depth': 2},
#      {'value': 'voyageur', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '3673': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'enfant',
#       'children': [{'value': 'nourrisson', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'femme', 'children': [], 'depth': 2}],
#     'depth': 1},
#    {'value': 'architecture',
#     'children': [{'value': 'tour', 'children': [], 'depth': 2},
#      {'value': 'colonne', 'children': [], 'depth': 2},
#      {'value': 'relief', 'children': [], 'depth': 2}],
#     'depth': 1},
#    {'value': 'arme',
#     'children': [{'value': 'épée', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '3674': {'value': 'root',
#   'children': [{'value': 'scène',
#     'children': [{'value': 'homme',
#       'children': [{'value': 'jeune', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'vieux', 'children': [], 'depth': 2},
#      {'value': 'femme', 'children': [], 'depth': 2},
#      {'value': 'croix', 'children': [], 'depth': 2},
#      {'value': 'échelle', 'children': [], 'depth': 2},
#      {'value': 'marteau', 'children': [], 'depth': 2},
#      {'value': 'clou', 'children': [], 'depth': 2},
#      {'value': 'tristesse', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '3675': {'value': 'root',
#   'children': [{'value': 'scène',
#     'children': [{'value': 'homme', 'children': [], 'depth': 2},
#      {'value': 'femme', 'children': [], 'depth': 2},
#      {'value': 'blessure', 'children': [], 'depth': 2},
#      {'value': 'échelle', 'children': [], 'depth': 2},
#      {'value': 'croix', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '368': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'femme', 'children': [], 'depth': 2},
#      {'value': 'jeune fille', 'children': [], 'depth': 2},
#      {'value': 'vêtement',
#       'children': [{'value': 'robe', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'tissu', 'children': [], 'depth': 2},
#      {'value': 'col', 'children': [], 'depth': 2},
#      {'value': 'gant', 'children': [], 'depth': 2},
#      {'value': 'bijou', 'children': [], 'depth': 2},
#      {'value': 'éventail', 'children': [], 'depth': 2},
#      {'value': 'instrument de musique', 'children': [], 'depth': 2},
#      {'value': 'draperie', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '3684': {'value': 'root',
#   'children': [{'value': 'animal',
#     'children': [{'value': 'oiseau', 'children': [], 'depth': 2},
#      {'value': 'écureuil', 'children': [], 'depth': 2},
#      {'value': 'serpent', 'children': [], 'depth': 2},
#      {'value': 'insecte',
#       'children': [{'value': 'papillon', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'araignée', 'children': [], 'depth': 2},
#      {'value': 'mite', 'children': [], 'depth': 2},
#      {'value': 'escargot', 'children': [], 'depth': 2}],
#     'depth': 1},
#    {'value': 'plante',
#     'children': [{'value': 'fleur', 'children': [], 'depth': 2},
#      {'value': 'sous-bois', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '3685': {'value': 'root',
#   'children': [{'value': 'nature morte',
#     'children': [{'value': 'fleur',
#       'children': [{'value': 'guirlande', 'children': [], 'depth': 3}],
#       'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '3686': {'value': 'root',
#   'children': [{'value': 'fleur',
#     'children': [{'value': 'pavot', 'children': [], 'depth': 2}],
#     'depth': 1},
#    {'value': 'scène',
#     'children': [{'value': 'femme', 'children': [], 'depth': 2},
#      {'value': 'enfant',
#       'children': [{'value': 'nourrisson', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'être imaginaire', 'children': [], 'depth': 2},
#      {'value': 'aile', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '3688': {'value': 'root',
#   'children': [{'value': 'insecte',
#     'children': [{'value': 'papillon', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '3690': {'value': 'root',
#   'children': [{'value': 'insecte',
#     'children': [{'value': 'papillon', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '3692': {'value': 'root', 'children': [], 'depth': 0},
#  '3695': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'homme', 'children': [], 'depth': 2},
#      {'value': 'religieux', 'children': [], 'depth': 2},
#      {'value': 'auréole', 'children': [], 'depth': 2},
#      {'value': 'soldat', 'children': [], 'depth': 2},
#      {'value': 'casque', 'children': [], 'depth': 2},
#      {'value': 'cuirasse', 'children': [], 'depth': 2},
#      {'value': 'arme', 'children': [], 'depth': 2},
#      {'value': 'torche', 'children': [], 'depth': 2},
#      {'value': 'croix', 'children': [], 'depth': 2},
#      {'value': 'cavalier', 'children': [], 'depth': 2},
#      {'value': 'vieille', 'children': [], 'depth': 2},
#      {'value': 'vieux', 'children': [], 'depth': 2},
#      {'value': 'être imaginaire',
#       'children': [{'value': 'nu', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'enfant', 'children': [], 'depth': 2},
#      {'value': 'aile', 'children': [], 'depth': 2},
#      {'value': 'dans les airs', 'children': [], 'depth': 2},
#      {'value': 'animal',
#       'children': [{'value': 'cheval', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'chien', 'children': [], 'depth': 2},
#      {'value': 'oiseau', 'children': [], 'depth': 2},
#      {'value': 'sphère', 'children': [], 'depth': 2},
#      {'value': 'maladie', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '370': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'homme',
#       'children': [{'value': 'de trois-quarts', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'moustache', 'children': [], 'depth': 2},
#      {'value': 'barbe', 'children': [], 'depth': 2},
#      {'value': 'sculpture', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '3704': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'femme',
#       'children': [{'value': 'de profil', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'oeil',
#       'children': [{'value': 'fermé', 'children': [], 'depth': 3}],
#       'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '3706': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'femme', 'children': [], 'depth': 2},
#      {'value': 'chapeau', 'children': [], 'depth': 2},
#      {'value': 'voile', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '3707': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'enfant',
#       'children': [{'value': 'expression du visage',
#         'children': [],
#         'depth': 3}],
#       'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '371': {'value': 'root',
#   'children': [{'value': 'scène',
#     'children': [{'value': 'homme', 'children': [], 'depth': 2},
#      {'value': 'femme',
#       'children': [{'value': 'nu', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'être imaginaire', 'children': [], 'depth': 2}],
#     'depth': 1},
#    {'value': 'architecture',
#     'children': [{'value': 'ville', 'children': [], 'depth': 2},
#      {'value': 'tour', 'children': [], 'depth': 2},
#      {'value': 'pont', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '3712': {'value': 'root',
#   'children': [{'value': 'figure',
#     'children': [{'value': 'femme', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '3713': {'value': 'root',
#   'children': [{'value': 'groupe de figures',
#     'children': [{'value': 'homme',
#       'children': [{'value': 'nu', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'femme', 'children': [], 'depth': 2},
#      {'value': 'boisson', 'children': [], 'depth': 2},
#      {'value': 'fontaine', 'children': [], 'depth': 2},
#      {'value': 'arbre', 'children': [], 'depth': 2},
#      {'value': 'fleur', 'children': [], 'depth': 2},
#      {'value': 'eau', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '373': {'value': 'root',
#   'children': [{'value': 'paysage',
#     'children': [{'value': 'montagne', 'children': [], 'depth': 2},
#      {'value': 'arbre', 'children': [], 'depth': 2},
#      {'value': 'eau',
#       'children': [{'value': 'rivière', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'rive', 'children': [], 'depth': 2}],
#     'depth': 1},
#    {'value': 'architecture',
#     'children': [{'value': 'bâtiment',
#       'children': [{'value': 'colonnade', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'maison', 'children': [], 'depth': 2},
#      {'value': 'pont', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  '3736': {'value': 'root',
#   'children': [{'value': 'paysage',
#     'children': [{'value': 'arbre',
#       'children': [{'value': 'tronc', 'children': [], 'depth': 3}],
#       'depth': 2},
#      {'value': 'forêt', 'children': [], 'depth': 2}],
#     'depth': 1}],
#   'depth': 0},
#  ...}

# %%
imagesEmbeddings = np.load(path_imagesEmbeddings)
objectsEmbeddings = np.load(path_objectsEmbeddings)
othersEmbeddings = np.load(path_othersEmbeddings)
print(np.mean(imagesEmbeddings), np.std(imagesEmbeddings))
print(np.mean(objectsEmbeddings), np.std(objectsEmbeddings))
print(np.mean(othersEmbeddings), np.std(othersEmbeddings))
# Out:
# 0.0009384602 0.036072187
# 0.00024383477 0.036083568
# 0.00022491075 0.03608369

# %%
DB = MockDB()
# Insert mock data
DB.insert_mock_data(FULL_DATASET.to_dict(orient="records"), imagesEmbeddings, ICONOGRAPHIES)
average_ico_length = [len(ico) for ico in ICONOGRAPHIES]
print("Average iconography length:", np.mean(average_ico_length))
# Out:
# Average iconography length: 4.003322259136213

# %%
DB.get_columns()
# Out:
# ['recordLanguage',
#  'recordID',
#  'DatabaseId',
#  'LinkToVubis',
#  'objectWork.creatorDescription',
#  'objectWork.termClassification',
#  'objectWork.workID',
#  'objectWork.titleText',
#  'objectWork.objectWorkType',
#  'objectWork.measurementsDescription',
#  'objectWork.termMaterialsTech',
#  'objectWork.inscriptionDescription',
#  'objectWork.creationDateDescription',
#  'creator.creatorAuthID',
#  'creator.lastNameCreator',
#  'creator.firstNameCreator',
#  'creator.birthDeathDatesPlacesCreatorDescription',
#  'creator.nationalityCreator',
#  'creator.deathDateCreator',
#  'creator.earliestActivityCreator',
#  'creator.copyrightHolderName',
#  'creator.copyrightStatement',
#  'measurements',
#  'creation.earliestDate',
#  'creation.latestDate',
#  'formalDescription.physicalAppearanceDescription',
#  'subjectMatter.subjectTerms',
#  'imageType',
#  'imageColor',
#  'low_res_filename',
#  'high_res_filename',
#  'DcaProjectNumber.DcaProjectID',
#  'objectWork.exhibitionDescription',
#  'creator.birthDateCreator',
#  'subjectMatter.iconographicTerms',
#  'relatedVisualDocumentation.imageWorkRelationshipType',
#  'relatedVisualDocumentation.imageType',
#  'relatedVisualDocumentation.imageDate',
#  'relatedVisualDocumentation.imageColor',
#  'relatedVisualDocumentation.imageCopyright',
#  'relatedVisualDocumentation.imageNumberOpacDisplay',
#  'relatedVisualDocumentation.imageID',
#  'relatedVisualDocumentation.imageOpacLink',
#  'relatedVisualDocumentation.imageIntranetLink',
#  'repositoryNumberVariant.repositoryNumberNoSpaces',
#  'subjectMatter.conceptualTerms',
#  'objectWork.objectWorkRemarks',
#  'relatedWorks',
#  'objectWork.titleVariant',
#  'relatedWorks.relatedWorkRecordID',
#  'relatedWorks.workRelationshipType',
#  'relatedWorks.relatedWorkTitle',
#  'relatedWorks.relatedWorkRepositoryNumber',
#  'relatedWorks.relatedWorkCreator',
#  'creator',
#  'creator.attributionQualifier',
#  'materials',
#  'materials.materialsName',
#  'materials.materialColorName',
#  'objectWork.componentsDescription',
#  'inscriptions.inscriptionType',
#  'inscriptions.inscriptionDates',
#  'inscriptions.inscriptionAuthorship',
#  'inscriptions.inscriptionLocation',
#  'relatedTextualReferences.sourceAuthorDescription',
#  'relatedTextualReferences.sourceAuthID',
#  'relatedTextualReferences.sourceTitle',
#  'relatedTextualReferences.citationPages',
#  'relatedTextualReferences.sourceAuthorName',
#  'relatedTextualReferences.sourcePublisher',
#  'relatedTextualReferences.sourcePublicationPlace',
#  'relatedTextualReferences.sourcePublicationYear',
#  'relatedTextualReferences.sourceCallNumber',
#  'formalDescription.stylesPeriodsDescription',
#  'subjectMatter.iconographicInterpretation',
#  'formalDescription.termStylesPeriods',
#  'creator.latestActivityCreator',
#  'creator.specificActivityCreatorDescription',
#  'context.associatedHistoricalAgent',
#  'relatedTextualReferences',
#  'inscriptions',
#  'relatedTextualReferences.sourceParallelTitle',
#  'relatedVisualDocumentation.imageViewDescription',
#  'creation.creationRemarks',
#  'techniques.techniquesName',
#  'techniques.extentTechniques',
#  'materials.extentMaterials',
#  'measurements.measurementsType',
#  'measurements.measurementsValue',
#  'measurements.measurementsUnit',
#  'measurements.measurementsShape',
#  'relatedVisualDocumentation.imageOpacLinkDetails',
#  'creation.placeLocAuthID',
#  'creation.creationPlace',
#  'subjectMatter.generalSubjectDescription',
#  'subjectMatter.specificSubjectIdentification',
#  'context.associatedHistoricalEventDescription',
#  'context.historicalEventType',
#  'context.historicalEventName',
#  'context.associatedArchitecturalContext',
#  'context.placeLocAuthID',
#  'context.associatedHistoricalPlaceName',
#  'exhibitions.exhibitionAuthID',
#  'exhibitions.exhibitionTitle',
#  'exhibitions.venueDates',
#  'exhibitions.catalogNumber',
#  'relatedWorks.linkRelatedWorksDocumentation',
#  'relatedWorks.relatedWorksOpacDisplay',
#  'relatedTextualReferences.sourceMaterialType',
#  'creator.biographyCreator',
#  'creator.linkBiographyDocumentation',
#  'relatedTextualReferences.linkExcerptDocument',
#  'relatedTextualReferences.excerptLinkOpacDisplay',
#  'materials.materialsTechDescription',
#  'copyrights.copyrightHolderName',
#  'copyrights.copyrightStatement',
#  'creator.attributionRemarks',
#  'relatedTextualReferences.linkFurtherBibliography',
#  'relatedTextualReferences.furtherBibliographyOpacDisplay',
#  'commissioner.commissionerName',
#  'commissioner.commissionerRole',
#  'componentsParts.componentsQuantity',
#  'componentsParts.componentsType',
#  'formalDescription.factureDescription',
#  'subjectMatter.subjectInterpretiveHistory',
#  'creator.linkAttributionDocumentation',
#  'relatedTextualReferences.citationType',
#  'materials.materialSourcePlace',
#  'creation',
#  'estimated_author_death',
#  'estimated_author_below_1955',
#  'is_copyright_validated',
#  'has_image',
#  'contains_subjectTerms',
#  'contains_iconographicTerms',
#  'contains_conceptualTerms',
#  'objectWorkType_is_tableau',
#  'objectWorkType_is_dessin',
#  'objectWorkType_is_aquarelle',
#  'objectWorkType_is_croquis',
#  'objectWorkType_is_gouache',
#  'objectWorkType_is_pastel',
#  'objectWorkType_is_papier',
#  'objectWorkType_is_affiche',
#  'objectWorkType_is_diptyque',
#  'objectWorkType_is_détrempe',
#  'objectWorkType_is_esquisse',
#  'objectWorkType_is_estampe',
#  'objectWorkType_is_grisaille',
#  'objectWorkType_is_photographie',
#  'objectWorkType_is_polyptyque',
#  'objectWorkType_is_retable',
#  'objectWorkType_is_sanguine',
#  'objectWorkType_is_triptyque',
#  'objectWorkType_is_ébauche',
#  'contains_desired_objectWorkType']

# %%
L = DB.get_unique_for_column("creation.earliestDate")
np.amin(L), np.amax(L)
# Out:
# (np.float64(1401.0), np.float64(1949.0))

# %%
FILTERS_SIMPLE = (
    {
        "type": "contains",
        "location": "iconography",
        "term": "homme"
    },
    "OR",
    (
        {
            "type": "interval",
            "location": "metadatas",
            "column": "creation.earliestDate",
            "min": 1948,
            "max": 1949
        },
        "OR",
        {
            "type": "interval",
            "location": "metadatas",
            "column": "creation.earliestDate",
            "min": 1910,
            "max": 1910
        }
    )
)

def formatResult(result):
    return {
        "recordID": result["recordID"],
        "title": result["objectWork.titleText"],
        "dates": (result["creation.earliestDate"], result["creation.latestDate"]),
        "iconography": result["iconography"],
    }

results = DB.query(filters=FILTERS_SIMPLE, query_embedding=None, page=0, page_size=5000)
print(len(results))

results = [formatResult(result) for result in results[:5]]
for result in results:
    print(result["title"], result["dates"])
    print(result["iconography"])
    print("")
# Out:
# 1490
# Portrait de Paul Verlaine (nan, nan)
# ['homme', 'barbe', 'figure']
#
# Les collègues (1884.0, 1884.0)
# ['intérieur', 'groupe de figures', 'chevalet', 'tableau', 'pinceau', 'homme', 'assis', 'femme', 'toile', 'livre', 'chapeau', 'atelier', 'table', 'fleur']
#
# Christ aux outrages (1878.0, 1930.0)
# ['animal', 'groupe de figures', 'soldat', 'couronne', 'cheval', 'coiffure', 'épine', 'homme', 'femme', 'arme', 'nu', 'casque', 'chien', 'lance', 'foule']
#
# Autoportrait (1855.0, 1865.0)
# ['pinceau', 'veste', 'homme', 'habit', 'livre', 'figure']
#
# L'homme au chapeau buse. Etude pour Roma (1846.0, 1912.0)
# ['vêtement', 'en pied', 'homme', 'chapeau', 'figure']
